# %%
from __future__ import division
from sklearn.cluster import KMeans
from numbers import Number
from pandas import DataFrame
import sys, codecs, numpy

# %%
class autovivify_list(dict):
  '''A pickleable version of collections.defaultdict'''
  def __missing__(self, key):
    '''Given a missing key, set initial value to an empty list'''
    value = self[key] = []
    return value

  def __add__(self, x):
    '''Override addition for numeric types when self is empty'''
    if not self and isinstance(x, Number):
      return x
    raise ValueError

  def __sub__(self, x):
    '''Also provide subtraction method'''
    if not self and isinstance(x, Number):
      return -1 * x
    raise ValueError

# %%
def build_word_vector_matrix(vector_file, n_words):
  '''Return the vectors and labels for the first n_words in vector file'''
  numpy_arrays = []
  labels_array = []
  with codecs.open(vector_file, 'r', 'utf-8') as f:
    for c, r in enumerate(f):
      sr = r.split()
      labels_array.append(sr[0])
      numpy_arrays.append( numpy.array([float(i) for i in sr[1:]]) )

      if c == n_words:
        return numpy.array( numpy_arrays ), labels_array

  return numpy.array( numpy_arrays ), labels_array

# %%
def find_word_clusters(labels_array, cluster_labels):
  '''Return the set of words in each cluster'''
  cluster_to_words = autovivify_list()
  for c, i in enumerate(cluster_labels):
    cluster_to_words[ i ].append( labels_array[c] )
  return cluster_to_words

# %%
if __name__ == "__main__":
  input_vector_file = "glove.42B.300d.txt" # Vector file input (e.g. glove.6B.300d.txt)
  n_words = 10000 # Number of words to analyze
  reduction_factor = .1 # Amount of dimension reduction {0,1}
  n_clusters = int( n_words * reduction_factor ) # Number of clusters to make
  df, labels_array = build_word_vector_matrix(input_vector_file, n_words)
  kmeans_model = KMeans(init='k-means++', n_clusters=n_clusters, n_init=10)
  kmeans_model.fit(df)

  cluster_labels  = kmeans_model.labels_
  cluster_inertia   = kmeans_model.inertia_
  cluster_to_words  = find_word_clusters(labels_array, cluster_labels)

  for c in cluster_to_words:
    print(cluster_to_words[c])
    print("\n")
# Out:
# [',', '.', 'and', 'is', 'that', 'it', 'are', 'as', 'be', 'have', 'was', 'not', '...', 'we', 'but', 'they', 'has', 'so', 'there', ';', 'which', 'no', 'also', 'had', 'been', 'were', 'now', 'only', 'good', 'well', 'work', 'because', 'even', 'where', 'made', 'being', 'while', 'still', 'both', 'since', 'without', 'however', 'having', 'yet', 'already', 'called', 'although', 'fine']
#
#
# ['the', 'a', 'for', 'with', "'s", 'this', 'or', 'an', 'one', 'first', 'each', 'every', 'another', 'second', 'person', 'least', 'single']
#
#
# ['to', 'you', 'your', 'will', 'can', 'do', 'if', 'get', 'how', 'them', 'see', 'make', 'use', 'should', 'need', 'want', 'take', "'ll", 'please', 'must', 'give', 'let', 'add', 'check', 'try', 'needs']
#
#
# ['of', 'all', 'some', 'other', 'any', 'these', 'most', 'two', 'many', 'such', 'those', 'few', 'several', 'couple', 'certain', 'lots', 'plenty']
#
#
# ['in', 'on', 'by', 'from', 'their', 'our', 'its', 'used', 'part', 'same', 'own', 'set', 'show', 'full', 'number', 'between', 'name', 'point', 'case', 'experience', 'within', 'body', 'following', 'based', 'general', 'level', 'personal', 'below', 'current', 'class', 'above', 'whole', 'given', 'works', 'original', 'action', 'natural', 'key', 'according', 'field', 'shows', 'clear', 'standard', 'present', 'common', 'similar', 'base', 'entire', 'master', 'actual', 'express']
#
#
# ['"', "'", '`', '``', 'clause']
#
#
# [':', 'information', 'view', 'details', 'title', 'info', 'description', 'detail', 'detailed', 'summary', 'descriptions']
#
#
# ['i', "n't", 'what', 'like', 'just', 'would', 'people', 'know', 'did', 'could', "'m", 'think', 'does', 'really', "'re", "'ve", 'look', 'why', 'say', 'things', 'never', 'something', 'ca', 'always', 'sure', 'thing', 'might', 'feel', 'ever', 'though', "'d", 'done', 'actually', 'doing', 'thought', 'someone', 'hope', 'believe', 'everyone', 'anyone', 'seen', 'probably', 'either', 'maybe', 'idea', 'looks', 'mean', 'seems', 'wanted', 'simply', 'guy', 'guys', 'wo', 'worth', 'seem', 'ones', 'tried', 'perhaps', 'agree', 'exactly', 'definitely', 'certainly', 'expect', 'wonder', 'meant', 'supposed']
#
#
# [')', '(', '-', '1', '2', '3', '4', '#', '0']
#
#
# ['at', 'my', 'about', 'up', 'out', 'me', 'us', 'here', 'over', 'back', 'way', 'go', 'right', 'off', 'down', 'going', 'around', 'next', 'got', 'place', 'come', 'today', 'live', 'put', 'away', 'start', 'making', 'getting', 'hard', 'working', 'run', 'started', 'went', 'past', 'face', 'close', 'trying', 'taking', 'stop', 'coming', 'move', 'running', 'instead', 'behind', 'hit', 'rest', 'ready', 'decided', 'pick', 'gone', 'waiting', 'ahead', 'busy']
#
#
# ['!', '.....', '....', '!!', '!!!', ':)', ':d', '!!!!', ';)', 'xd', ':p', ':-)', '!!!!!', '=)', 'yay', '!!!!!!', ';-)', 'hehe']
#
#
# ['?', 'reblogged', '??', '???', '?!', 'wtf', 'thumbs', '????', 'huh', '!?', 'xx']
#
#
# ['he', 'his', 'her', 'she', 'him', 'himself', 'herself']
#
#
# ['more', 'than', 'much', 'too', 'little', 'long', 'better', 'lot', 'less', 'enough', 'far', 'bit', 'short', 'rather', 'longer']
#
#
# ['|', 'views', 'posted', 'post', 'comments', 'comment', 'reply', 're', 'posts', 'quote', 'permalink', 'admin', 'anonymous', 'replies', 'trackback', 'contribs']
#
#
# ['new', 'york', 'ny', 'jersey', 'nj', 'nyc', 'brooklyn', 'manhattan']
#
#
# ['when', 'time', 'into', 'then', 'after', 'through', 'before', 'again', 'left', 'once', 'until', 'together', 'later', 'soon', 'turn', 'finally', 'quickly', 'eventually', 'till']
#
#
# ['$', '£', 'usd', 'us$', 'eur']
#
#
# ['&', 'etc.', 'etc']
#
#
# ['who', 'lives', 'character', 'whose', 'named', 'characters', 'whom', 'native', 'lived']
#
#
# ['/', '--', '+', '~', '\\', '^', '---', '----', 'bb']
#
#
# ['[', ']']
#
#
# ['may', '20', '15', '30', '18', '14', '13', '16', '25', '24', '17', '21', '19', '22', '23', '26', '28', '27', '29', '31']
#
#
# ['am', 'pm']
#
#
# ['>', 'related', 'tags', '>>', 'category', 'filed', 'tagged', 'tag', 'categories', '›', 'uncategorized', 'miscellaneous']
#
#
# ['home', 'free', 'find', 'found', 'real', 'looking', 'results', 'finding', 'searching', 'discover', 'locate']
#
#
# ['very', 'pretty', 'quite', 'extremely', 'slightly', 'fairly', 'relatively', 'somewhat', 'attractive', 'decent', 'sharp', 'incredibly', 'equally', 'balanced', 'realistic', 'surprising', 'surprisingly', 'neat', 'reasonably', 'appealing', 'modest', 'dull', 'smoothly', 'straightforward']
#
#
# ['said', 'says', 'tell', 'talk', 'told', 'ask', 'asked', 'saying', 'talking', 'speak', 'asking', 'speaking', 'speech', 'telling', 'thinks', 'spoke']
#
#
# ['%', 'per', 'percent', 'average', 'cent', 'percentage', 'cents']
#
#
# ['day', 'year', 'years', 'last', 'days', 'ago', 'week', 'months', 'month', 'weeks']
#
#
# ['great', 'nice', 'beautiful', 'perfect', 'excellent', 'wonderful', 'awesome', 'friendly', 'lovely', 'fantastic', 'gorgeous', 'fabulous', 'romantic', 'pleasant', 'superb', 'sunny', 'charming', 'intimate', 'terrific', 'refreshing', 'handsome', 'delightful', 'lively', 'cozy', 'inviting', 'welcoming']
#
#
# ['best', 'top', 'quality', 'highest', 'premier', 'finest', 'hottest']
#
#
# ['love', 'happy', 'enjoy', 'likes', 'loved', 'watching', 'liked', 'enjoyed', 'loves', 'loving', 'enjoying', 'beloved', 'enjoys']
#
#
# ['2012', '2011', '2010', '2009', '2008', '2013', '@', '2014']
#
#
# ['=', '_', '{', '}', '<', 'int', '__', 'void', 'null', 'bytes', 'prev', '<<', 'var', 'hotel_review', 'diff']
#
#
# ['world', 'american', 'country', 'america', 'nation', 'americans']
#
#
# ['5', '10', '6', '7', '8', '12', '11', '9']
#
#
# ['business', 'companies', 'businesses', 'firms', 'corporations', 'entrepreneurs']
#
#
# ['life', 'heart', 'mind', 'eyes', 'nature', 'moment', 'memory', 'eye', 'self', 'dream', 'reality', 'thoughts', 'brain', 'vision', 'soul', 'dreams', 'moments', 'memories', 'inner', 'hearts', 'sight', 'mood', 'minds', 'collective', 'genius', 'imagination', 'consciousness', 'spirits', 'conscious', 'infinite', 'senses', 'brains', 'ego', 'dreaming']
#
#
# ['help', 'support', 'helps', 'effort', 'helped', 'helping', 'efforts', 'aid', 'assistance', 'assist', 'raise', 'promote', 'supporting', 'encourage', 'awareness', 'contribute', 'raising', 'aids', 'foster', 'promoting', 'encouraging', 'facilitate', 'heal', 'strengthen', 'educate']
#
#
# ['video', 'videos', 'trailer', 'clip', 'tape', 'clips', 'cam', 'footage', 'trailers', 'reel', 'tapes', 'loops']
#
#
# ['online', 'electronic', 'catalog', 'on-line', 'catalogue', 'offline', '24/7']
#
#
# ['high', 'low', 'higher', 'lower', 'upper']
#
#
# ['game', 'play', 'games', 'player', 'playing', 'players', 'played', 'plays']
#
#
# ['read', 'review', 'reviews', 'reading', 'writing', 'write', 'tips', 'advice', 'recommend', 'helpful', 'recommended', 'feedback', 'suggestions', 'recommendations', 'reviewed', 'pros', 'reviewing', 'researching', 'commenting', 'recommends']
#
#
# ['service', 'services', 'solutions', 'provider', 'providers', 'healthcare', 'carrier', 'vendor', 'carriers', 'billing']
#
#
# ['school', 'public', 'social', 'education', 'resources', 'schools', 'arts', 'resource', 'educational', 'academy', 'journalism', 'literacy']
#
#
# ['state', 'ohio', 'michigan', 'illinois', 'kansas', 'indiana', 'minnesota', 'pennsylvania', 'iowa', 'wisconsin', 'missouri', 'nebraska']
#
#
# ['city', 'town', 'district', 'village', 'cities', 'communities', 'urban', 'rural', 'towns', 'counties', 'districts', 'villages', 'neighborhoods', 'countryside', 'suburban']
#
#
# ['system', 'power', 'control', 'remote', 'controls', 'controlled', 'controlling']
#
#
# ['news', 'blog', 'articles', 'feed', 'blogs', 'rss', 'subscribe', 'blogging', 'blogger', 'podcast', 'feeds', 'headlines', 'bloggers', 'weblog', 'podcasts']
#
#
# ['site', 'web', 'website', 'internet', 'content', 'sites', 'pages', 'websites', 'domain', 'niche', 'directories', 'domains', 'e-commerce']
#
#
# ['under', 'section', 'subject', 'shall', 'limited', 'unless', 'except', 'otherwise', 'reserved', 'duty', 'non', 'remaining', 'plain', 'sections', 'exception', 'ordinary', 'applies', 'substitute', 'exceptions', 'excluding']
#
#
# ['available', 'including', 'provide', 'special', 'include', 'added', 'features', 'space', 'includes', 'further', 'plus', 'provided', 'additional', 'included', 'addition', 'unit', 'extra', 'direct', 'entry', 'feature', 'active', 'and/or', 'units', 'adding', 'separate', 'serving', 'combination', 'combined', 'extensive', 'serves', 'optional', 'convenience', 'supplied', 'arrangements', 'additions', 'ample']
#
#
# ['using', 'type', 'form', 'code', 'source', 'example', 'simple', 'step', 'method', 'figure', 'uses', 'reference', 'setting', 'background', 'structure', 'steps', 'forms', 'elements', 'sample', 'examples', 'element', 'typical', 'instance', 'reverse', 'composition', 'conventional', 'grid', 'matrix', 'stack', 'alternate', 'catalyst']
#
#
# ['page', 'click', 'link', 'links', 'profile', 'directory', 'edit', 'calendar', 'navigation', 'contacts', 'wikipedia', 'bookmark', 'faq', 'portal', 'homepage', 'advertise', 'wiki', 'disclaimer', 'timeline', 'brochure', 'testimonials', 'widget', 'sitemap', 'dashboard']
#
#
# ['big', 'large', 'huge', 'largest', 'biggest', 'massive', 'giant', 'vast', 'enormous', 'mega']
#
#
# ['s', '€', 'â', 'll', '¢', 'rm', '¡']
#
#
# ['family', 'living', 'parents', 'families', 'individuals', 'residents', 'citizens', 'persons', 'household', 'veterans', 'seniors', 'homeless', 'immigrants', 'households']
#
#
# ['music', 'song', 'lyrics', 'songs', 'tracks', 'tune', 'soundtrack', 'tunes', 'lyric', 'hindi']
#
#
# ['company', 'corporation', 'corp.', 'holdings', 'corp', 'nasdaq', 'nyse']
#
#
# ['price', 'rate', 'prices', 'rates', 'pricing']
#
#
# ['book', 'books', 'ebook', 'kindle', 'textbooks', 'ebooks']
#
#
# ['old', 'young', 'age', 'older', 'ages', 'younger', 'aged', 'aging', 'elderly', 'elder', 'youngest']
#
#
# ['search', 'listings', 'browse', 'keywords', 'searches', 'browsing', 'keyword', 'searched', 'classifieds', 'finder']
#
#
# ['black', 'white', 'red', 'green', 'blue', 'brown', 'dark', 'pink', 'yellow', 'orange', 'bright', 'grey', 'gray', 'purple', 'colored', 'ribbon', 'metallic', 'pale', 'stripes', 'neon', 'dots']
#
#
# ['house', 'building', 'build', 'built', 'commercial', 'construction', 'complex', 'housing', 'buildings', 'residential', 'structures']
#
#
# ['three', 'four', 'five', 'six', 'ten', 'seven', 'eight', 'nine', 'hundred', 'thousand', 'twenty', 'twelve', 'thirty', 'fifty', 'fifteen', 'eleven', 'forty']
#
#
# ['man', 'baby', 'boy', 'boys', 'kid', 'lil', 'daddy']
#
#
# ['during', 'end', 'date', 'early', 'late', 'period', 'starting', 'stage', 'began', 'beginning', 'begin', 'starts', 'ended', 'ends', 'dates', 'begins', 'phase', 'ending', 'mid', 'stages', 'begun', 'sometime', 'longest', 'earliest', 'lasted']
#
#
# ['different', 'local', 'among', 'various', 'individual', 'groups', 'types', 'variety', 'multiple', 'numerous', 'kinds', 'diverse', 'amongst', 'sorts', 'varied', 'varieties', 'backgrounds']
#
#
# ['health', 'diet', 'lifestyle', 'nutrition', 'wellness', 'nutritional']
#
#
# ['group', 'national', 'community', 'society', 'association', 'organization', 'union', 'organizations', 'ministry', 'organized', 'commerce', 'organisation', 'federation', 'guild', 'associations', 'non-profit', 'organizing', 'advocacy', 'nonprofit']
#
#
# ['team', 'teams', 'coach', 'coaching', 'coaches', 'squad', 'athletes', 'roster', 'athlete', 'trainers']
#
#
# ['times', 'half', 'daily', 'round', 'double', 'count', 'twice', 'split', 'repeat', 'pitch', 'triple', 'counts', 'rounds', 'repeated', 'counting', 'quarters', 'counted', 'doubles', 'sweep']
#
#
# ['car', 'cars', 'auto', 'vehicle', 'driving', 'truck', 'vehicles', 'trucks', 'passenger', 'automobile', 'pickup', 'mileage']
#
#
# ['area', 'near', 'location', 'located', 'centre', 'situated', 'residence', 'plaza', 'adjacent', 'conveniently']
#
#
# ['buy', 'order', 'items', 'purchase', 'orders', 'purchased', 'inventory', 'purchasing', 'discounts', 'priced', 'shipped', 'ordering', 'paypal', 'purchases', 'bargain', 'checkout', 'expired']
#
#
# ['money', 'pay', 'account', 'cash', 'paid', 'payment', 'paying', 'accounts', 'bonus', 'earn', 'payments', 'credits', 'reward', 'pays', 'rewards', 'earning', 'bonuses', 'owe']
#
#
# ['water', 'lake', 'river', 'lakes', 'rivers', 'pond', 'canal', 'dam', 'basin', 'reservoir']
#
#
# ['keep', 'kept', 'keeping', 'remain', 'keeps', 'constantly', 'whilst', 'maintained', 'consistently', 'continually', 'continuously']
#
#
# ['data', 'function', 'associated', 'primary', 'values', 'object', 'internal', 'processing', 'distribution', 'external', 'functions', 'fields', 'e.g.', 'defined', 'i.e.', 'objects', 'array', 'generated', 'secondary', 'usage', 'specified', 'variable', 'distributed', 'static', 'parallel', 'parameters', 'derived', 'partial', 'generating', 'attributes', 'variables', 'mapping', 'cluster', 'attribute', 'buffer', 'parameter', 'transmitted', 'binary', 'eg']
#
#
# ['small', 'larger', 'smaller', 'bigger', 'tiny', 'wider', 'smallest']
#
#
# ['x', 'length', 'mm', 'inch', 'height', 'inches', 'cm', 'width', 'diameter']
#
#
# ['list', 'listed', 'names', 'index', 'listing', 'lists', 'entries', 'titles', 'profiles', 'genealogy', 'compiled', 'sorted', 'surname']
#
#
# ['children', 'kids', 'child', 'adult', 'youth', 'parent', 'childhood', 'toddler', 'juvenile']
#
#
# ['design', 'custom', 'designs', 'designer', 'architecture', 'designers', 'designing', 'architectural']
#
#
# ['women', 'men', 'ladies', 'mens', 'womens']
#
#
# ['call', 'calls', 'calling', 'telephone']
#
#
# ['care', 'medical', 'patients', 'doctor', 'patient', 'surgery', 'doctors', 'clinic', 'hospitals', 'physician', 'physicians', 'surgical', 'dentist', 'surgeon', 'pediatric']
#
#
# ['download', 'downloads', 'serial', 'crack', 'torrent', 'keygen', 'rapidshare']
#
#
# ['program', 'programs', 'programming', 'programme', 'programmes']
#
#
# ['night', 'friday', 'morning', 'sunday', 'saturday', 'monday', 'thursday', 'tuesday', 'wednesday', 'evening', 'yesterday', 'tonight', 'tomorrow', 'afternoon']
#
#
# ['products', 'product', 'brand', 'supply', 'manufacturer', 'wholesale', 'manufacturers', 'brands', 'suppliers', 'supplier', 'vendors', 'manufactured', 'makers', 'manufacture', 'distributor', 'distributors']
#
#
# ['against', 'attack', 'attacks', 'threat', 'strike', 'enemy', 'destroy', 'defend', 'enemies', 'defence', 'strikes', 'opponent', 'attacked', 'opponents', 'invasion', 'raid', 'defending', 'attacking', 'allies', 'opposing']
#
#
# ['center', 'centers', 'offices', 'centres', 'clinics']
#
#
# ['line', 'along', 'street', 'main', 'drive', 'across', 'cut', 'outside', 'track', 'middle', 'walk', 'ground', 'lines', 'straight', 'block', 'cross', 'onto', 'walking', 'edge', 'direction', 'corner', 'sides', 'border', 'directions', 'blocks', 'opposite', 'strip', 'loop', 'narrow', 'crossing']
#
#
# ['thanks', 'thank', 'welcome', 'hi', 'hello', 'dear', 'wishes', 'congratulations', 'cheers', 'congrats', 'goodbye', 'merry', 'bye', 'darling', 'hugs', 'greetings', 'hug']
#
#
# ['food', 'eat', 'healthy', 'fat', 'eating', 'foods', 'raw', 'feeding', 'ate', 'lean', 'vegetarian', 'vegan', 'eaten', 'healthier', 'appetite', 'eats']
#
#
# ['open', 'opening', 'closed', 'opened', 'closing', 'opens', 'closure', 'openings', 'closes']
#
#
# ['university', 'campus', 'columbia', 'oxford', 'cambridge', 'duke', 'harvard', 'berkeley', 'commons', 'princeton', 'yale']
#
#
# ['room', 'chair', 'sit', 'sitting', 'standing', 'desk', 'hanging', 'lounge', 'bench', 'lying', 'sits', 'lap', 'beside', 'couch', 'laying', 'staring']
#
#
# ['god', 'lord', 'jesus', 'spirit', 'christ', 'holy', 'grace', 'heaven', 'worship', 'sin', 'glory', 'divine', 'praise', 'gods', 'eternal', 'mercy', 'sacrifice', 'allah', 'salvation', 'prophet', 'faithful', 'sins', 'covenant']
#
#
# ['change', 'role', 'relationship', 'generation', 'changing', 'shift', 'evolution', 'differences', 'discovery', 'gap', 'transition', 'survival', 'formation', 'experiment', 'scenario', 'intervention', 'radical', 'transformation', 'dynamics', 'implications', 'advances', 'migration', 'phenomenon', 'adaptation', 'shifts', 'progression']
#
#
# ['2007', '2006', '2005', '2004', '2003', '2000', '2002', '2001']
#
#
# ['hotel', 'inn', 'accommodation', 'lodge', 'accommodations', 'motel', 'lodging', 'b&b', 'tripadvisor', 'marriott', 'hostel']
#
#
# ['job', 'jobs', 'workers', 'employment', 'labor', 'employee', 'salary', 'employer', 'labour', 'worker', 'careers', 'employers', 'disability', 'hiring', 'unemployment', 'recruitment', 'workplace', 'occupation', 'salaries', 'wage', 'workforce', 'wages', 'payroll', 'occupational']
#
#
# ['course', 'training', 'practice', 'learning', 'teacher', 'teaching', 'courses', 'teachers', 'instruction', 'classroom', 'studying', 'curriculum', 'instructor', 'practicing', 'instructors']
#
#
# ['contact', 'email', 'name@domain.com', 'e-mail', 'fax', 'tel']
#
#
# ['sale', 'sales', 'stock', 'sell', 'sold', 'bought', 'buying', 'selling', 'goods', 'ebay', 'dealer', 'auction', 'merchandise', 'sells', 'swap', 'auctions', 'buys']
#
#
# ['side', 'front', 'bar', 'seat', 'rear', 'interior', 'seats', 'wing', 'hood', 'tail', 'bumper']
#
#
# ['able', 'save', 'continue', 'meet', 'bring', 'opportunity', 'easily', 'enter', 'reach', 'lose', 'advantage', 'advance', 'manage', 'managed', 'unable', 'effectively', 'collect', 'communicate', 'gather', 'safely', 'acquire', 'preserve', 'arrange', 'organize', 'retain']
#
#
# ['county', 'lincoln', 'franklin', 'madison', 'jefferson', 'township', 'municipal', 'springfield', 'monroe', 'montgomery', 'albany', 'chester', 'pa.', 'salem', 'hometown', 'rouge', 'vernon']
#
#
# ['phone', 'mobile', 'phones', 'nokia', 'cellular', 'sim']
#
#
# ['research', 'study', 'studies', 'institute', 'scientific', 'sciences', 'genetics']
#
#
# ['software', 'freeware', 'screenshot', 'shareware']
#
#
# ['march', 'june', 'april', 'january', 'july', 'february', 'october', 'september', 'november', 'december', 'august']
#
#
# ['art', 'painting', 'poster', 'artwork', 'posters', 'paintings', 'framed', 'sculpture']
#
#
# ['easy', 'easier', 'expensive', 'efficient', 'convenient', 'accessible', 'ease', 'harder', 'cheaper', 'complicated', 'handy', 'lighter', 'easiest', 'safer', 'navigate', 'tricky', 'hassle']
#
#
# ['story', 'stories', 'legend', 'quest', 'adventures', 'tale', 'tales', 'fairy', 'legends', 'saga', 'chronicles']
#
#
# ['light', 'led', 'lights', 'lamps', 'lit', 'fog']
#
#
# ['de', 'la', 'le', 'un', 'du', 'les', 'pour', 'au', 'par', 'à', 'sur']
#
#
# ['market', 'global', 'economy', 'demand', 'consumer', 'rise', 'markets', 'worldwide', 'domestic', 'trend', 'rising', 'decline', 'recession', 'inflation', 'reserves', 'volumes', 'surge']
#
#
# ['office', 'department', 'police', 'officer', 'officers', 'commissioner', 'deputy', 'sheriff', 'clerk', 'spokesman', 'inspector']
#
#
# ['government', 'law', 'security', 'policy', 'federal', 'agency', 'administration', 'foreign', 'civil', 'authority', 'affairs', 'authorities', 'enforcement', 'immigration', 'bureau', 'customs', 'irs', 'homeland']
#
#
# ['international', 'europe', 'european', 'eu', 'euro']
#
#
# ['states', 'united', 'u.s.', 'usa', 'kingdom', 'nations']
#
#
# ['report', 'reports', 'survey', 'statistics', 'census', 'estimates', 'surveys']
#
#
# ['makes', 'comes', 'gets', 'takes', 'goes', 'gives', 'runs', 'hits', 'brings', 'turns', 'leads', 'moves', 'finds', 'adds', 'drives', 'meets', 'puts', 'creates', 'sees', 'picks', 'reads', 'tries', 'stops', 'walks', 'receives', 'carries', 'saves', 'owns', 'reaches', 'raises', 'draws', 'loses', 'decides', 'builds', 'enters', 'pulls', 'manages', 'expects', 'touches']
#
#
# ['important', 'process', 'required', 'needed', 'effective', 'necessary', 'useful', 'require', 'appropriate', 'requires', 'essential', 'critical', 'proper', 'task', 'relevant', 'instructions', 'procedure', 'obtain', 'careful', 'vital', 'guidance', 'tasks', 'routine', 'sufficient', 'applying', 'crucial', 'placement', 'execution', 'minimal', 'beneficial', 'adequate', 'requiring', 'timely', 'obtaining', 'execute', 'thorough']
#
#
# ['series', 'season', 'summer', 'weekend', 'spring', 'fan', 'fans', 'upcoming', 'preview', 'seasons', 'lineup', 'premiere', 'tuned', 'finale', 'recap']
#
#
# ['size', 'medium', 'sizes', 'sized']
#
#
# ['air', 'conditioning', 'conditioner']
#
#
# ['hours', 'minutes', 'hour', 'seconds', 'minute', 'min', 'mins', 'hrs']
#
#
# ['john', 'david', 'mark', 'peter', 'ben', 'daniel', 'matthew', 'jonathan', 'luke', 'samuel', 'benjamin', 'joel', 'nathan', 'joshua', 'timothy', 'gabriel']
#
#
# ['south', 'north', 'west', 'region', 'western', 'southern', 'northern', 'eastern', 'pacific', 'regions', 'province', 'northwest', 'territory', 'southwest', 'southeast', 'northeast', 'peninsula']
#
#
# ['project', 'complete', 'final', 'projects', 'completed', 'progress', 'completion', 'assignment', 'completing', 'assignments', 'renovation']
#
#
# ['management', 'division', 'operations', 'operation', 'operator', 'acquisition', 'operational', 'logistics']
#
#
# ['development', 'developing', 'managing', 'implementation', 'framework', 'implement', 'implemented', 'implementing', 'establishing', 'governance', 'unified', 'coding']
#
#
# ['100', '50', '40', '60', '80', '90', '70', '75', '65', '120', 'mph']
#
#
# ['history', 'culture', 'traditional', 'cultural', 'ancient', 'greek', 'tradition', 'legacy', 'folk', 'generations', 'sacred', 'cultures', 'centuries', 'traditions', 'myth', 'medieval', 'origins', 'indigenous', 'celtic', 'renaissance', 'ritual']
#
#
# ['friends', 'friend', 'ex', 'kiss', 'girlfriend', 'boyfriend', 'lovers', 'buddy', 'friendship', 'lover', 'mate', 'affair', 'companion', 'stranger', 'pal', 'cheating', 'gentleman']
#
#
# ['party', 'birthday', 'anniversary', 'celebrate', 'celebration', 'ceremony', 'occasion', 'eve', 'easter', 'valentine', 'tribute', 'thanksgiving', 'parade', 'occasions', 'graduation', 'celebrating', 'celebrated', 'reunion', 'carnival', 'feast', 'fireworks', 'celebrates', 'celebrations']
#
#
# ['bad', 'poor', 'seriously', 'mention', 'obviously', 'worse', 'unfortunately', 'worst', 'apparently', 'worry', 'considering', 'hopefully', 'usual', 'obvious', 'anymore', 'besides', 'wondering', 'aside', 'somehow', 'admit', 'gotten', 'anybody', 'mistake', 'terrible', 'blame', 'suppose', 'hardly', 'mess', 'fault', 'honestly', 'lately', 'mistakes', 'shame', 'excuse', 'expecting', 'assuming', 'bother', 'awful', 'sadly', 'nowhere', 'sooner', 'clue', 'complain', 'fortunately', 'nowadays', 'luckily', 'n’t', 'wasted', 'hurts', 'hated', 'frankly', 'imo', 'dislike', 'meantime', 'frustrating', 'complaining', 'unfortunate', 'guessing', 'hardest', 'apologize', 'hype', 'thankfully', 'disappointing', 'scare']
#
#
# ['head', 'heads', 'headed', 'heading', 'crossed', 'spotted', 'landed', 'flew', 'alley']
#
#
# ['problem', 'issue', 'problems', 'error', 'trouble', 'solve', 'difficulty', 'solved', 'solving']
#
#
# ['fun', 'interesting', 'exciting', 'challenging', 'entertaining', 'fascinating', 'enjoyable', 'passionate', 'informative', 'memorable', 'productive', 'inspiring', 'meaningful', 'compelling', 'satisfying', 'rewarding', 'thoughtful']
#
#
# ['students', 'college', 'student', 'academic', 'graduate', 'faculty', 'scholarship', 'semester', 'undergraduate', 'tuition', 'graduates', 'scholarships', 'mba', 'enrolled']
#
#
# ['watch', 'watches', 'replica']
#
#
# ['hot', 'sexy', 'lesbian', 'fetish', 'webcam', 'babes', 'lingerie', 'bra', 'erotic', 'naughty', 'panties', 'bondage', 'stockings', 'booty']
#
#
# ['photo', 'photos', 'image', 'pictures', 'picture', 'images', 'slideshow', 'enlarge', 'thumbnail']
#
#
# ['movie', 'film', 'movies', 'films', 'documentary']
#
#
# ['media', 'tv', 'radio', 'channel', 'entertainment', 'television', 'satellite', 'channels', 'bbc', 'broadcast', 'fm', 'hdtv', 'broadcasting']
#
#
# ['others', 'understand', 'yourself', 'myself', 'ways', 'thinking', 'themselves', 'interested', 'beyond', 'seeing', 'imagine', 'aware', 'readers', 'explain', 'realize', 'folks', 'appreciate', 'experiences', 'personally', 'knowing', 'everyday', 'familiar', 'ourselves', 'assume', 'recognize', 'curious', 'understood', 'deeply', 'deeper', 'possibilities', 'convinced', 'alike', 'relate', 'embrace', 'believing', 'grasp', 'realise', 'discovering', 'imagined', 'happier']
#
#
# ['members', 'meeting', 'council', 'committee', 'meetings', 'elected', 'representatives', 'appointed', 'advisory', 'committees', 'presidents']
#
#
# ['version', 'demo', 'tutorial', 'beta', 'mario', 'mod', 'cheat', 'tutorials', 'hack', 'avatar', 'clone', 'sims', 'screenshots', 'dev', 'prototype', 'warcraft']
#
#
# ['offer', 'offers', 'private', 'providing', 'deals', 'offered', 'offering', 'premium', 'dedicated', 'exclusive', 'affordable', 'packages', 'unlimited', 'nationwide', 'catering', 'hospitality', 'specials', 'offerings', 'inclusive']
#
#
# ['anything', 'everything', 'fact', 'means', 'nothing', 'true', 'kind', 'else', 'reason', 'matter', 'cannot', 'wrong', 'sort', 'whatever', 'alone', 'truth', 'knows', 'absolutely', 'none', 'clearly', 'nor', 'feels', 'false', 'pure', 'neither', 'impossible', 'nobody', 'lies', 'lie', 'absolute']
#
#
# ['file', 'text', 'copy', 'pdf', 'format', 'document', 'documents', 'documentation', 'xml', 'doc']
#
#
# ['road', 'highway', 'hwy', 'boulevard', 'interstate', 'intersection']
#
#
# ['article', 'note', 'recent', 'written', 'previous', 'wrote', 'notes', 'earlier', 'sources', 'mentioned', 'quotes', 'described', 'edited', 'brief', 'noted', 'follows', 'suggested', 'authors', 'linked', 'discussed', 'referred', 'refer', 'references', 'commented', 'pointed', 'commentary', 'referring', 'quoted', 'cited', 'remarks', 'headline', 'highlighted', 'quoting', 'excerpt']
#
#
# ['often', 'especially', 'sometimes', 'difficult', 'particularly', 'tend', 'frequently', 'situations', 'rarely', 'occasionally', 'frequent', 'encounter', 'painful', 'habit', 'occasional', 'tends', 'encountered', 'tendency']
#
#
# ['park', 'parks', 'gardens', 'attractions', 'recreation', 'beaches', 'recreational', 'museums']
#
#
# ['came', 'took', 'taken', 'lost', 'upon', 'land', 'held', 'gave', 'worked', 'turned', 'brought', 'changed', 'spent', 'met', 'moved', 'served', 'followed', 'placed', 'showed', 'raised', 'appeared', 'saved', 'carried', 'entered', 'drawn', 'laid', 'fed', 'remained', 'destroyed', 'captured', 'lands', 'settled', 'gathered', 'accompanied', 'abandoned', 'restored', 'occupied']
#
#
# ['hand', 'position', 'hold', 'hands', 'carry', 'roll', 'holding', 'draw', 'positions', 'holds', 'lay', 'carrying', 'grip', 'flip', 'handed', "'em", 'fold', 'backs', 'stake', 'dice', 'whip']
#
#
# ['yes', 'oh', 'ok', 'guess', 'sorry', 'yeah', 'hey', 'anyway', 'mine', 'luck', 'okay', 'ya', 'kinda', 'ill', 'gotta', 'ah', 'btw', 'um', 'pmi', 'yea', 'heck', 'tho', 'alright', 'anyways', 'uh', 'yep', 'ami', 'eh', 'hmm', 'kidding', 'blah', 'hmmm', 'p.s.', 'til', 'nope', "y'"]
#
#
# ['share', 'giving', 'rich', 'sharing', 'shared', 'spread', 'bringing', 'saving', 'valuable', 'generous', 'spreading']
#
#
# ['access', 'allow', 'apply', 'allowed', 'transfer', 'allowing', 'permit', 'permitted', 'accommodate', 'permits', 'transfers']
#
#
# ['visit', 'visitors', 'visiting', 'visited', 'visits', 'visitor']
#
#
# ['become', 'became', 'highly', 'considered', 'becomes', 'becoming', 'remains', 'widely', 'increasingly', 'proved', 'regarded', 'deemed', 'traditionally', 'politically', 'historically']
#
#
# ['points', 'goal', 'goals', 'scored', 'scores', 'scoring', 'assists']
#
#
# ['plan', 'plans', 'decision', 'budget', 'commission', 'approved', 'proposed', 'draft', 'approval', 'bid', 'proposal', 'agenda', 'deadline', 'proposals', 'recommendation', 'controversial', 'preliminary', 'approve', 'interim', 'propose']
#
#
# ['technology', 'tech', 'technologies', 'innovative', 'innovation', 'technological', 'innovations']
#
#
# ['possible', 'future', 'deal', 'lead', 'cause', 'likely', 'chance', 'potential', 'involved', 'situation', 'condition', 'serious', 'damage', 'possibly', 'treat', 'unknown', 'minor', 'immediate', 'possibility', 'ultimately', 'causing', 'chances', 'involve', 'unlikely', 'pose', 'leak', 'viable']
#
#
# ['windows', 'vista', 'xp']
#
#
# ['sex', 'porn', 'pics', 'nude', 'naked', 'pic', 'xxx', 'bikini']
#
#
# ['event', 'hall', 'convention', 'reception', 'stadium', 'venue', 'arena', 'pub', 'booth', 'venues', 'expo', 'pavilion']
#
#
# ['card', 'cards']
#
#
# ['value', 'total', 'amount', 'balance', 'maximum', 'minimum', 'equal', 'zero', 'estimated', 'amounts', 'equivalent', 'sum', 'excess', 'yield', 'roughly', 'exceed', 'proportion', 'fraction', 'minus']
#
#
# ['board', 'boards']
#
#
# ['learn', 'learned', 'teach', 'lessons', 'taught', 'lesson', 'basics', 'teaches', 'beginner', 'beginners']
#
#
# ['question', 'questions', 'answer', 'answers', 'answered', 'quiz']
#
#
# ['property', 'estate', 'rental', 'rent', 'properties', 'houses', 'rentals', 'lease', 'mls', 'flats']
#
#
# ['create', 'existing', 'generate', 'combine', 'introduce', 'customized', 'modify', 'adopt', 'transform', 'utilize', 'incorporate', 'combining', 'utilizing', 'customize', 'structured', 'employ', 'distribute', 'integrate', 'proprietary', 'construct', 'adapt', 'complement', 'merge']
#
#
# ['computer', 'devices', 'computers', 'desktop', 'networking', 'electronics', 'computing', 'pcs', 'printers', 'laptops', 'gadgets']
#
#
# ['parts', 'systems', 'hardware', 'components', 'assembly', 'component', 'functional', 'structural', 'modules', 'composite']
#
#
# ['member', 'independent', 'representative', 'rep', 'supervisor', 'ambassador']
#
#
# ['whether', 'interest', 'terms', 'term', 'particular', 'fair', 'purpose', 'reasons', 'basis', 'responsible', 'respect', 'parties', 'actions', 'responsibility', 'concerned', 'decisions', 'purposes', 'interests', 'matters', 'reasonable', 'regardless', 'conduct', 'circumstances', 'favor', 'extent', 'necessarily', 'formal', 'regard', 'consideration', 'relation', 'sole', 'ownership', 'grounds', 'demands', 'regards', 'acceptable', 'absence', 'establishment', 'intent', 'determination', 'discipline', 'intention', 'profession', 'legitimate', 'obligation', 'compromise', 'premises', 'justify', 'privilege', 'necessity', 'whatsoever', 'unfair', 'discretion', 'favour', 'intentions', 'considerations', 'his/her', 'constitute']
#
#
# ['insurance', 'agent', 'agents', 'dealers', 'broker', 'movers', 'brokers', 'relocation', 'advisors', 'servicing', 'leasing', 'appraisal', 'realtors']
#
#
# ['girl', 'girls', 'woman', 'teen', 'lady', 'virgin', 'chick', 'teenage', 'kissing', 'skinny', 'teenager', 'maid']
#
#
# ['c', 'b', 'm', 't', 'd', 'r', 'l', 'f', 'g', 'h', 'p', 'j', 'k', 'q', 'z']
#
#
# ['energy', 'solar', 'electricity', 'renewable']
#
#
# ['million', 'billion', 'dollars', 'millions', 'billions', 'trillion']
#
#
# ['network', 'via', 'connection', 'port', 'connect', 'connected', 'connections', 'terminal', 'connecting', 'hub', 'gateway', 'wired', 'connects']
#
#
# ['war', 'force', 'military', 'army', 'forces', 'command', 'soldiers', 'troops', 'armed', 'soldier', 'corps', 'commander', 'naval', 'rebel', 'civilian', 'allied', 'infantry', 'deployed']
#
#
# ['user', 'device', 'interface', 'module', 'controller', 'api', 'interfaces', 'ui']
#
#
# ['credit', 'loan', 'mortgage', 'loans', 'financing', 'payday', 'lenders', 'lender', 'lending', 'mortgages']
#
#
# ['president', 'director', 'executive', 'chief', 'secretary', 'vice', 'ceo', 'chairman', 'vp']
#
#
# ['human', 'earth', 'planet', 'universe', 'humans', 'humanity', 'beings', 'civilization', 'mankind']
#
#
# ['words', 'word', 'phrase', 'phrases', 'expressions', 'vocabulary']
#
#
# ['travel', 'journey', 'traveling', 'travelers', 'travels', 'travelling', 'traveled', 'traveler']
#
#
# ['cost', 'costs', 'fee', 'fees', 'expenses', 'expense']
#
#
# ['store', 'shop', 'shopping', 'stores', 'retail', 'shops', 'factory', 'outlet', 'mall', 'grocery', 'warehouse', 'outlets', 'depot', 'retailer', 'walmart']
#
#
# ['almost', 'itself', 'completely', 'nearly', 'totally', 'mostly', 'basically', 'entirely', 'acting', 'unlike', 'literally', 'driven', 'merely', 'essentially', 'largely', 'opposed', 'virtually', 'neutral', 'mere', 'partly', 'identical', 'invisible', 'partially', 'seemingly', 'practically', 'technically', 'purely', 'supposedly', 'invented', 'altogether', 'transformed', 'utterly']
#
#
# ['model', 'models', 'modeling', 'simulation']
#
#
# ['style', 'collection', 'ideas', 'fashion', 'classic', 'creative', 'vintage', 'contemporary', 'inspired', 'inspiration', 'artistic', 'retro', 'inspire', 'creations', 'inspirational']
#
#
# ['club', 'golf', 'clubs']
#
#
# ['known', 'popular', 'leading', 'famous', 'recognized', 'oldest', 'legendary', 'prominent', 'respected', 'well-known', 'renowned', 'distinguished', 'award-winning', 'internationally', 'prestigious', 'influential', 'nationally', 'iconic']
#
#
# ['box', 'storage', 'fill', 'filled', 'empty', 'boxes', 'packaging', 'basket', 'packed', 'container', 'filling', 'frames', 'plates', 'packing', 'tray', 'tin', 'containers', 'baskets', 'envelope', 'cans']
#
#
# ['events', 'festival', 'concert', 'concerts', 'festivals', 'fest']
#
#
# ['color', 'colors', 'colour', 'colours', 'shade', 'shades']
#
#
# ['church', 'temple', 'churches', 'bishop', 'saints', 'pastor', 'parish', 'pope', 'baptist', 'priest', 'chapel', 'cathedral', 'trinity', 'abbey']
#
#
# ['test', 'testing', 'tests', 'inspection']
#
#
# ['major', 'career', 'greatest', 'fame', 'contributions', 'contribution', 'contributed', 'achievements', 'contributing', 'notable', 'appearances', 'contributor', 'contributors']
#
#
# ['performance', 'overall', 'improve', 'greater', 'improved', 'improvement', 'efficiency', 'enhance', 'boost', 'improving', 'greatly', 'improvements', 'enhanced', 'productivity', 'effectiveness', 'dramatically', 'enhancement', 'maximize', 'improves', 'considerably', 'visibility', 'enhancing']
#
#
# ['industry', 'industrial', 'sector', 'manufacturing', 'industries', 'automotive', 'enterprises', 'pharmaceutical', 'sectors']
#
#
# ['uk', 'england', 'ireland', 'irish', 'britain', 'scotland', 'wales', 'scottish', 'dublin']
#
#
# ['range', 'wide', 'ranging', 'ranges']
#
#
# ['marketing', 'campaign', 'promotion', 'affiliate', 'pr', 'promotional', 'promo', 'campaigns', 'promotions', 'branding', 'publicity']
#
#
# ['digital', 'camera', 'cameras', 'canon', 'gps', 'zoom', 'mp', 'nikon']
#
#
# ['rights', 'peace', 'justice', 'freedom', 'constitution', 'liberty', 'democracy', 'independence', 'unity', 'equality']
#
#
# ['court', 'trial', 'judge', 'appeal', 'supreme', 'courts', 'judgment', 'judges', 'jury', 'ruling', 'appeals', 'ruled']
#
#
# ['due', 'result', 'loss', 'cases', 'significant', 'caused', 'initial', 'resulting', 'ongoing', 'involving', 'losses', 'suffered', 'substantial', 'destruction', 'subsequent', 'apparent', 'resulted', 'toll', 'considerable', 'collapse', 'anticipated', 'widespread', 'sustained', 'withdrawal', 'consequence', 'witnessed']
#
#
# ['sound', 'hear', 'heard', 'voice', 'sounds', 'listen', 'hearing', 'listening', 'noise', 'crowd', 'loud', 'silent', 'voices', 'silence', 'echo', 'horn', 'sounded', 'bells']
#
#
# ['send', 'message', 'sent', 'mail', 'messages', 'sending', 'spam', 'emails', 'mailing', 'sms', 'sends', 'incoming']
#
#
# ['remember', 'leave', 'follow', 'wish', 'wait', 'miss', 'forget', 'lucky', 'forever', 'hide', 'lets', 'everybody', 'shut', 'wake', 'hang', 'somebody', 'ignore', 'blind', 'letting', 'recall', 'forgot', 'quit', 'skip', 'trick', 'forgotten', 'shake', 'spell', 'reminds', 'rip', 'remind', 'fool', 'dig', 'dare', 'reminder', 'crush', 'forgive', 'swear', 'hurry', 'pretend', 'cheer', 'fade', 'remembering']
#
#
# ['professional', 'experienced', 'registered', 'certified', 'qualified', 'licensed', 'skilled', 'accredited', 'competent']
#
#
# ['miles', 'km', 'mi', 'mile']
#
#
# ['english', 'french', 'german', 'spanish', 'italian', 'dutch', 'polish', 'swiss', 'swedish', 'portuguese', 'danish']
#
#
# ['cover', 'covered', 'covers', 'sheet', 'covering', 'sheets', 'panels', 'cloth', 'backing']
#
#
# ['beach', 'island', 'bay', 'coast', 'atlantic', 'cape', 'shore', 'sandy', 'harbor', 'surf', 'nova', 'tide', 'cod', 'harbour', 'isle']
#
#
# ['issues', 'safety', 'privacy', 'challenges', 'concerns', 'concern', 'priority', 'complaints', 'addressed', 'threats', 'fears', 'addressing', 'priorities', 'worries', 'barriers']
#
#
# ['stay', 'comfortable', 'guests', 'nights', 'stayed', 'staying', 'overnight', 'stays', 'weekends']
#
#
# ['address', 'received', 'receive', 'request', 'prior', 'receiving', 'requests', 'addresses', 'copies', 'permission', 'appointment', 'requested', 'checks', 'confirm', 'authorized', 'consent', 'confirmation', 'recipient', 'pending', 'receipt', 'postal', 'confidential', 'notified', 'corrections']
#
#
# ['financial', 'bank', 'economic', 'corporate', 'finance', 'accounting', 'banking', 'fiscal', 'monetary', 'finances']
#
#
# ['guide', 'edition', 'basic', 'advanced', 'chapter', 'manual', 'comprehensive', 'introduction', 'practical', 'overview', 'guides', 'chapters', 'revised', 'encyclopedia', 'intermediate', 'outline', 'handbook', 'essentials', 'atlas', 'anatomy', 'in-depth']
#
#
# ['oil', 'oils', 'crude']
#
#
# ['star', 'stars', 'cast', 'actor', 'actors', 'actress', 'starring']
#
#
# ['press', 'published', 'magazine', 'journal', 'papers', 'publication', 'collections', 'publications', 'newspapers', 'magazines', 'bulletin', 'journals', 'editions', 'newsletters']
#
#
# ['latest', 'update', 'updated', 'updates', 'revision', 'newer', 'updating', 'upgrades', 'upgraded', 'rom', 'up-to-date', 'firmware', 'refresh']
#
#
# ['return', 'leaving', 'returned', 'returns', 'arrived', 'arrive', 'returning', 'arrival', 'entering', 'departure', 'arrives', 'arriving']
#
#
# ['provides', 'application', 'users', 'solution', 'tool', 'allows', 'platform', 'virtual', 'integrated', 'supports', 'enable', 'dynamic', 'capture', 'flexible', 'developers', 'real-time', 'enables', 'enabled', 'built-in', 'automated', 'embedded', 'mobility', 'enabling', 'messaging', 'accessibility']
#
#
# ['win', 'won', 'winning', 'victory', 'wins', 'earned', 'champion', 'streak', 'triumph']
#
#
# ['paper', 'print', 'printing', 'printed', 'prints', 'canvas']
#
#
# ['hair', 'beauty', 'makeup', 'salon', 'lip', 'cosmetic', 'cosmetics']
#
#
# ['weight', 'pounds', 'lbs', 'lb', 'pound', 'kg', 'weigh', 'grams']
#
#
# ['staff', 'employees', 'managers', 'personnel', 'administrative', 'assigned', 'duties', 'responsibilities', 'departments', 'audit', 'administrators', 'supervision']
#
#
# ['item', 'shipping', 'availability', 'cart', 'quantity', 'sku', 'bulk', 'vat', 'quantities', 'qty']
#
#
# ['death', 'dead', 'alive', 'ghost', 'dying', 'dies', 'souls']
#
#
# ['sports', 'sport', 'leisure', 'sporting']
#
#
# ['google', 'microsoft', 'yahoo', 'messenger', 'gmail', 'msn', 'skype', 'aol']
#
#
# ['gold', 'silver', 'copper', 'bronze', 'platinum', 'coin', 'coins', 'plated']
#
#
# ['london', 'manchester', 'birmingham', 'liverpool', 'bristol', 'edinburgh', 'yorkshire', 'glasgow', 'derby', 'newcastle', 'hull', 'leeds', 'brighton']
#
#
# ['act', 'bill', 'laws', 'legislation', 'reform', 'bills', 'amendment', 'regulation', 'provisions', 'passage', 'provision', 'abortion', 'amended', 'amendments']
#
#
# ['east', 'central', 'regional']
#
#
# ['wedding', 'gift', 'gifts', 'personalized', 'weddings', 'invitation', 'announcements', 'greeting', 'favors', 'invitations']
#
#
# ['usually', 'regular', 'normal', 'generally', 'typically', 'normally', 'regularly', 'naturally', 'commonly', 'processed']
#
#
# ['science', 'math', 'physics', 'biology', 'chemistry', 'mathematics', 'mechanics', 'quantum', 'mathematical', 'geography']
#
#
# ['san', 'california', 'los', 'angeles', 'francisco', 'diego', 'jose', 'antonio', 'sf', 'juan', 'sacramento', 'cal', 'cruz', 'l.a.', 'calif.', 'luis']
#
#
# ['release', 'released', 'releases', 'releasing']
#
#
# ['currently', 'recently', 'originally', 'reported', 'previously', 'discovered', 'viewed', 'retrieved', 'confirmed', 'newly', 'acquired', 'formerly', 'accessed']
#
#
# ['table', 'tables', 'chairs', 'seating']
#
#
# ['record', 'records', 'studio', 'recording', 'recorded', 'recordings', 'recorder', 'playback']
#
#
# ['stuff', 'cool', 'piece', 'pieces', 'bunch', 'fancy', 'bits', 'geek', 'extras', 'props']
#
#
# ['fire', 'burn', 'burning', 'burns', 'flame', 'burned', 'fires', 'flames']
#
#
# ['inside', 'deep', 'walls', 'sand', 'dust', 'rocks', 'exposed', 'bare', 'beneath', 'arch', 'underneath', 'overhead']
#
#
# ['sun', 'sat', 'wed', 'mon', 'fri', 'tue', 'thu']
#
#
# ['favorite', 'favourite', 'favorites', 'classics', 'selections', 'playlist', 'fav', 'bookmarks']
#
#
# ['third', 'fourth', 'fifth', 'sixth', 'seventh', 'consecutive', 'innings', 'eighth', 'ninth', 'inning']
#
#
# ['dog', 'cat', 'pet', 'cats', 'pets']
#
#
# ['u', 'im', 'dont', 'hate', 'gonna', 'cant', 'wanna', 'ai', 'alot', 'didnt', 'wont', 'ive', 'doesnt', 'nt', 'cuz', 'n`t', 'isnt', 'ppl', 'theres', 'cos']
#
#
# ['saw', 'knew', 'looked', 'felt', 'seemed', 'noticed', 'watched', 'realized', 'suddenly', 'talked', 'replied', 'barely', 'figured', 'remembered', 'reminded', 'touched', 'wondered', 'waited', 'hoped', 'laughed', 'listened', 'awhile', 'briefly', 'happily', 'quietly', 'smiled', 'glance', 'disappeared', 'wished', 'struggled']
#
#
# ['tax', 'benefits', 'benefit', 'coverage', 'spending', 'taxes', 'savings', 'cuts', 'scheme', 'retirement', 'compensation', 'welfare', 'pension', 'medicare', 'schemes', 'incentive', 'incentives', 'stimulus', 'taxpayers', 'budgets']
#
#
# ['rock', 'pop', 'punk', 'indie']
#
#
# ['cheap', 'discount', 'lowest', 'cheapest', 'inexpensive', 'discounted']
#
#
# ['fast', 'speed', 'super', 'quick', 'rapid', 'fastest']
#
#
# ['choose', 'choice', 'options', 'consider', 'select', 'option', 'selection', 'alternative', 'selected', 'decide', 'prefer', 'choices', 'chosen', 'preferred', 'choosing', 'chose', 'selecting', 'alternatives', 'preference', 'deciding', 'opt', 'preferences', 'cons']
#
#
# ['forum', 'thread', 'topic', 'discussion', 'forums', 'topics', 'chat', 'debate', 'conversation', 'threads', 'discussions', 'conversations', 'q&a', 'moderator']
#
#
# ['n', 'e', 'w', 'o', 'da', 'di', 'em']
#
#
# ['areas', 'map', 'places', 'distance', 'spot', 'restaurants', 'locations', 'maps', 'explore', 'nearby', 'bars', 'streets', 'destination', 'surrounding', 'spots', 'spaces', 'underground', 'tourist', 'nearest', 'attraction', 'closest', 'tourists', 'sights', 'crowded', 'proximity']
#
#
# ['created', 'production', 'produce', 'produced', 'directed', 'producing', 'producer', 'studios', 'productions', 'produces', 'producers']
#
#
# ['amazing', 'ultimate', 'extreme', 'incredible', 'outstanding', 'brilliant', 'impressive', 'epic', 'intense', 'exceptional', 'dramatic', 'extraordinary', 'remarkable', 'endless', 'magical', 'tremendous', 'sheer', 'vivid']
#
#
# ['treatment', 'therapy', 'massage', 'healing', 'treatments', 'therapeutic', 'therapist']
#
#
# ['designed', 'fully', 'ideal', 'suit', 'suitable', 'equipped', 'suits', 'suited', 'ideally', 'semi', 'tailored', 'modular']
#
#
# ['band', 'jazz', 'solo', 'blues', 'orchestra', 'duo', 'trio', 'symphony', 'ensemble']
#
#
# ['author', 'interview', 'discuss', 'reader', 'tells', 'talks', 'writes', 'explained', 'believes', 'explains', 'asks', 'describes', 'speaks', 'creator', 'discusses', 'explaining', 'understands', 'considers', 'maya', 'explores']
#
#
# ['sign', 'flag', 'logo', 'labels', 'blank', 'tattoo', 'banner', 'flags', 'stickers', 'badge', 'sticker', 'magnet', 'logos', 'tattoos']
#
#
# ['customer', 'customers', 'clients', 'client', 'transaction', 'transactions']
#
#
# ['mr.', 'paul', 'dr.', 'michael', 'mike', 'tom', 'jack', 'steve', 'scott', 'bob', 'jim', 'mr', 'ed', 'brian', 'don', 'dan', 'dave', 'frank', 'tim', 'sam', 'jeff', 'tony', 'eric', 'patrick', 'ron', 'gary', 'pat', 'dean', 'rob', 'bruce', 'rick', 'jay', 'alan', 'jon', 'larry', 'greg', 'phil', 'jerry', 'ken', 'steven', 'terry', 'roger', 'craig', 'keith', 'fred', 'robin', 'barry', 'chuck', 'carl', 'ted', 'dennis', 'pete', 'todd', 'neil', 'doug', 'randy', 'glenn']
#
#
# ['changes', 'effect', 'conditions', 'impact', 'factors', 'factor', 'causes', 'influence', 'affect', 'affected', 'affects', 'influenced', 'alter', 'affecting', 'impacts', 'influences', 'altered']
#
#
# ['join', 'attend', 'participants', 'participate', 'volunteer', 'invited', 'attended', 'volunteers', 'joining', 'invite', 'attending', 'encouraged', 'participating', 'alumni', 'fellowship', 'participated', 'invites', 'organised', 'attendees']
#
#
# ['equipment', 'machine', 'supplies', 'machines', 'machinery', 'welding']
#
#
# ['hotels', 'resort', 'resorts']
#
#
# ['washington', 'dc', 'downtown', 'seattle', 'wa', 'portland', 'd.c.', 'capitol']
#
#
# ['strong', 'heavy', 'solid', 'powerful', 'strength', 'weak', 'stable', 'stronger', 'robust', 'strongest']
#
#
# ['mother', 'son', 'born', 'father', 'wife', 'died', 'daughter', 'husband', 'brother', 'married', 'marriage', 'birth', 'uncle', 'spouse', 'cousin', 'marry', 'fathers', 'grandfather']
#
#
# ['homes', 'apartment', 'apartments', 'villa', 'condo', 'villas', 'condos']
#
#
# ['king', 'royal', 'queen', 'prince', 'princess', 'kings', 'crown', 'imperial', 'queens']
#
#
# ['unique', 'styles', 'signature', 'unusual', 'authentic', 'bold', 'distinct', 'colorful', 'exotic', 'accent', 'striking', 'vibrant', 'distinctive', 'characteristic', 'aesthetic', 'accents']
#
#
# ['forward', 'moving', 'towards', 'putting', 'toward', 'push', 'turning', 'closer', 'rolling', 'hitting', 'picking', 'pushing', 'reaching', 'pulling', 'stopping', 'gently', 'placing', 'pointing', 'touching', 'pressing', 'pressed', 'approaching', 'forcing', 'leap', 'backwards', 'stepping', 'shifting', 'stretching', 'halfway']
#
#
# ['door', 'window', 'doors', 'garage', 'gate', 'exterior', 'gates', 'sliding', 'curtain']
#
#
# ['jan', 'feb', 'mar', 'apr', 'dec', 'jun', 'oct', 'nov', 'aug', 'sep', 'jul', "'12", "'11"]
#
#
# ['christmas', 'holiday', 'vacation', 'holidays', 'seasonal']
#
#
# ['tools', 'applications', 'capacity', 'enterprise', 'intelligence', 'infrastructure', 'integration', 'capabilities', 'functionality', 'capability', 'platforms', 'automation', 'deployment', 'leverage']
#
#
# ['james', 'smith', 'johnson', 'lee', 'jones', 'jackson', 'williams', 'ray', 'davis', 'jordan', 'allen', 'lewis', 'wright', 'carter', 'robinson', 'wade', 'bryant']
#
#
# ['fall', 'drop', 'rose', 'falls', 'fell', 'dropped', 'falling', 'drops', 'fallen', 'dropping', 'spike', 'rises']
#
#
# ['wall', 'stand', 'stands', 'tall', 'holder', 'rack', 'bow', 'holders', 'tier', 'umbrella']
#
#
# ['bed', 'beds', 'sofa', 'mattress']
#
#
# ['material', 'materials', 'recycled', 'metals']
#
#
# ['st.', 'st', 'saint']
#
#
# ['conference', 'proceedings', 'symposium', 'ieee']
#
#
# ['inc.', 'co.', 'co', 'inc', 'ltd', 'llc', 'ltd.', 'incorporated', 'realty']
#
#
# ['language', 'languages', 'translation', 'dictionary', 'spoken', 'texts', 'translated', 'translate', 'spelling', 'arabic', 'grammar', 'hebrew']
#
#
# ['obama', 'bush', 'clinton', 'romney', 'barack', 'mccain', 'palin', 'kerry', 'hillary', 'gore', 'reagan', 'mitt']
#
#
# ['sense', 'confidence', 'pride', 'personality', 'attitude', 'wisdom', 'insight', 'creativity', 'essence', 'motivation', 'appreciation', 'courage', 'patience', 'harmony', 'qualities', 'clarity', 'wit', 'spark', 'lacking', 'enthusiasm', 'perfection', 'tolerance', 'warmth', 'compassion', 'simplicity', 'profound', 'abundance', 'virtue', 'curiosity']
#
#
# ['lol', 'wow', 'shit', 'thats', 'damn', 'haha', 'dude', 'ur', 'omg', 'yo', 'whats', 'vid', 'hahaha', 'bro', 'hes', 'dat', 'lmao', 'sooo', 'wat', 'fuckin']
#
#
# ['skin', 'facial', 'acne', 'skins']
#
#
# ['album', 'cd', 'label', 'albums', 'debut', 'ep', 'lp', 'beatles', 'compilation']
#
#
# ['china', 'japan', 'republic', 'korea', 'vietnam', 'sri', 'taiwan', 'lanka']
#
#
# ['screen', 'display', 'touch', 'panel', 'hd', 'keyboard', 'lcd', 'screens', 'plasma', 'projector']
#
#
# ['engine', 'powered', 'portable', 'generator']
#
#
# ['texas', 'tx', 'houston', 'fort', 'dallas', 'austin', 'charlotte', 'ut', 'arlington', 'raleigh']
#
#
# ['files', 'folder', 'folders']
#
#
# ['increase', 'levels', 'increased', 'reduce', 'increasing', 'reduced', 'reduction', 'increases', 'significantly', 'reducing', 'concentration', 'intake', 'decrease', 'decreased', 'circulation', 'elevated']
#
#
# ['dvd', 'disc', 'blu-ray', 'cds', 'dvds', 'discs']
#
#
# ['server', 'servers', 'ftp']
#
#
# ['canada', 'canadian', 'ontario', 'montreal', 'quebec', 'provincial']
#
#
# ['manager', 'firm', 'developer', 'specialist', 'consulting', 'consultant', 'hr', 'analyst', 'administrator', 'trainer', 'coordinator', 'advisor', 'architect', 'technician', 'planner', 'freelance']
#
#
# ['shot', 'shooting', 'shoot', 'shots', 'bullet', 'shoots', 'shooter']
#
#
# ['blood', 'liver', 'lung', 'cholesterol', 'kidney', 'fatty', 'prostate', 'colon', 'organs', 'metabolism']
#
#
# ['modern', 'smart', 'casual', 'intelligent', 'sophisticated', 'clever', 'refined', 'elaborate']
#
#
# ['clean', 'cleaning', 'removal', 'wash', 'carpet', 'brush', 'steam', 'laundry', 'cleaner', 'vacuum', 'washing', 'cleaned', 'washed', 'cleanup', 'cleaners', 'wipe']
#
#
# ...
#
#
# ['acid', 'chemical', 'chemicals', 'compound', 'compounds', 'acids', 'substances']
#
#
# ['formed', 'consists', 'divided', 'constructed', 'comprising', 'comprises', 'composed', 'forming', 'separated', 'consisting', 'assembled', 'segments', 'consist', 'comprised']
#
#
# ['guarantee', 'warranty', 'guaranteed', 'lifetime', 'refund', 'guarantees']
#
#
# ['stream', 'streaming', 'streams', 'flows', 'flowing']
#
#
# ['accurate', 'accuracy', 'precision', 'precise', 'reliability']
#
#
# ['memorial', 'funeral', 'buried', 'cemetery', 'grave', 'burial']
#
#
# ['processes', 'mechanism', 'biological', 'molecular', 'underlying', 'mechanisms']
#
#
# ['attached', 'insert', 'attachment', 'anchor', 'pins', 'glue', 'attach', 'removable', 'inserted']
#
#
# ['newspaper', 'herald', 'tribune', 'chronicle']
#
#
# ['perfectly', 'carefully', 'painted', 'nicely', 'beautifully', 'decorated', 'crafted', 'professionally']
#
#
# ['gaming', 'gameplay', 'gamers', 'battlefield', 'multiplayer', 'rpg']
#
#
# ['mouse', 'tiger', 'lion', 'robot', 'monkey', 'rabbit', 'snake', 'jungle', 'rat', 'spider', 'elephant', 'ninja', 'skull', 'frog', 'penguin']
#
#
# ['modified', 'modification', 'modifications']
#
#
# ['publisher', 'publishing', 'publishers']
#
#
# ['protein', 'proteins']
#
#
# ['laser', 'optical', 'imaging', 'diagnostic']
#
#
# ['64', '99', '95', '72', '85', '66', '98', '69', '68', '67', '96', '88', '71', '78', '76', '74', '77', '73', '91', '84', '82', '97', '86', '92', '81', '79', '89', '83', '93', '87', '94']
#
#
# ['smoking', 'tobacco', 'cigarette', 'cigarettes']
#
#
# ['lens', 'sunglasses', 'lenses']
#
#
# ['era', 'decades', 'decade', 'boom', '1980s', '1970s', '1960s', '80s', '1990s']
#
#
# ['belt', 'adjustable', 'strap', 'harness', 'belts', 'straps', 'elastic']
#
#
# ['expression', 'gene', 'sequence', 'dna', 'genetic', 'genes', 'sequences']
#
#
# ['mirror', 'mirrors', 'vanity']
#
#
# ['1000', '1500', '3000', '5000']
#
#
# ['chart', 'charts', 'diagram', 'graph', 'breakdown']
#
#
# ['rank', 'stats', 'ranked', 'recruiting', 'ranking', 'rankings', 'ranks', 'recruit']
#
#
# ['20th', '21st', '10th', '18th', '11th', '15th', '12th', '17th', '16th', '13th', '14th', '25th', '30th', '24th', '28th', '22nd', '26th', '23rd', '27th', '29th', '31st']
#
#
# ['muscle', 'muscles', 'joints']
#
#
# ['kick', 'punch', 'knock', 'kicked', 'kicks', 'wwe', 'kicking', 'slam']
#
#
# ['wave', 'frequency', 'magnetic', 'waves', 'beam', 'intensity', 'pulse', 'sensitivity', 'velocity', 'interval']
#
#
# ['toronto', 'bc', 'vancouver', 'ab', 'alberta', 'ottawa', 'calgary']
#
#
# ['php', 'java', 'python', 'c++', 'apache']
#
#
# ['denver', 'orleans', 'indianapolis', 'nascar', 'jacksonville']
#
#
# ['seo', 'wordpress', 'optimization']
#
#
# ['slowly', 'rapidly', 'emerging', 'gradually', 'emerged', 'disappear', 'emerge']
#
#
# ['roof', 'yard', 'deck', 'patio', 'fence', 'shed', 'backyard', 'porch']
#
#
# ['kelly', 'amy', 'laura', 'michelle', 'rachel', 'ashley', 'julie', 'heather', 'amanda', 'katie', 'holly', 'melissa', 'sara', 'rebecca', 'stephanie', 'christine', 'andrea', 'jenny', 'beth', 'liz', 'jill', 'shannon', 'erin', 'molly', 'carrie']
#
#
# ['palm', 'desert', 'tropical', 'paradise', 'sunset', 'caribbean', 'retreat', 'sunrise', 'sanctuary', 'bali', 'hawaiian']
#
#
# ['liquid', 'fluid', 'ph', 'hydrogen', 'urine', 'dye']
#
#
# ['converter', 'convert', 'conversion', 'formats', 'converted', 'batch', 'converting']
#
#
# ['branch', 'branches']
#
#
# ['hero', 'dragon', 'heroes', 'knight', 'sword', 'warrior', 'mighty', 'brave', 'warriors', 'knights', 'clan']
#
#
# ['investigation', 'investigate', 'inquiry', 'fbi', 'probe', 'investigations', 'investigating', 'investigators']
#
#
# ['certificate', 'certification', 'certificates']
#
#
# ['depth', 'dimensions', 'dimension', 'projection', 'latitude', 'elevation', 'coordinates', 'focal', 'radius']
#
#
# ['lift', 'lifting', 'wheelchair', 'lifts']
#
#
# ['scheduled', 'cancel', 'booked', 'cancelled', 'cancellation']
#
#
# ['permanent', 'long-term', 'temporary', 'short-term']
#
#
# ['prayer', 'pray', 'blessed', 'bless', 'prayers', 'blessing', 'praying', 'blessings']
#
#
# ['governor', 'mayor', 'senator', 'rep.', 'sen.', 'gov.', 'senators']
#
#
# ['bond', 'bonds', 'bail']
#
#
# ['heating', 'contractor', 'drain', 'plumbing', 'milesno', 'appliance', 'remodeling', 'roofing']
#
#
# ['ha', 'na', 'sa', 'si', 've', 'ba', 'po', 'ce', 'mai', 'je', 'ta', 'ti', 'cu', 'mag', 'ni', 'pe']
#
#
# ['se', 'ne', 'nw', 'sw', 'pl']
#
#
# ['tone', 'contrast', 'texture', 'slight', 'mild', 'subtle', 'hint', 'delicate', 'hints', 'tones', 'crisp']
#
#
# ['transmission', 'steering', 'suspension', 'brake', 'exhaust', 'brakes', 'clutch', 'hydraulic', 'pedal', 'ignition']
#
#
# ['isbn', 'paperback', 'hardcover', 'isbn-13']
#
#
# ['jpg', 'gif', 'png']
#
#
# ['monster', 'alien', 'beast', 'vampire', 'creatures', 'zombie', 'pokemon', 'monsters', 'creature', 'aliens', 'robots', 'dragons', 'zombies']
#
#
# ['coat', 'tan', 'fur', 'coats']
#
#
# ['printer', 'scan', 'scanner', 'scanning']
#
#
# ['lab', 'laboratory', 'labs', 'laboratories']
#
#
# ['aircraft', 'rc', 'helicopter', 'aerial']
#
#
# ['adobe', 'photoshop']
#
#
# ['prison', 'arrested', 'guilty', 'jail', 'accused', 'arrest', 'convicted', 'conviction', 'sentenced']
#
#
# ['craft', 'crafts', 'diy', 'handmade', 'hobby', 'pottery', 'antiques']
#
#
# ['chrome', 'polished', 'nickel']
#
#
# ['teens', 'pregnant', 'couples', 'mothers', 'moms', 'parenting', 'wives', 'teenagers']
#
#
# ['101', '125', '105', '115', '103', '111', '107', '123', '109', '116', '121', '118', '113', '122', '119', '117', '124', '126', '127']
#
#
# ['formula', 'gp', 'f1', 'prix']
#
#
# ['halloween', 'costume', 'mask', 'costumes', 'pirate']
#
#
# ['bone', 'tissue', 'bones', 'tooth']
#
#
# ['ink', 'cartridge', 'toner', 'cartridges']
#
#
# ['latin', 'hispanic', 'latino']
#
#
# ['kim', 'jennifer', 'jessica', 'amber', 'lauren', 'nicole', 'tiffany', 'christina', 'megan', 'lindsay', 'lopez']
#
#
# ['twin', 'angels', 'twins']
#
#
# ['juice', 'olive', 'lemon', 'mint', 'coconut', 'lime', 'peel', 'vinegar', 'peach', 'citrus']
#
#
# ['revolution', 'regime', 'soviet', 'revolutionary', 'communist', 'hitler', 'propaganda', 'nazi', 'socialist', 'capitalism']
#
#
# ['pregnancy', 'acute', 'bleeding', 'complications', 'mortality', 'defects', 'cardiac']
#
#
# ['utility', 'utilities']
#
#
# ['victoria', 'sydney', 'melbourne', 'brisbane', 'perth', 'vic']
#
#
# ['photographs', 'portrait', 'photograph', 'reproduction', 'photographic']
#
#
# ['template', 'layout', 'templates', 'header', 'cms']
#
#
# ['1.5', '2.5', '3.5', 'approx', '4.5', '0.5', '5.5', '7.5', '6.5', '8.5', '0.1']
#
#
# ['honda', 'toyota', 'nissan', 'civic', 'yamaha', 'suzuki', 'mazda', 'accord']
#
#
# ['empire', 'emperor', 'reign']
#
#
# ['hip', 'hop', 'rap', 'funk', 'hip-hop']
#
#
# ['antique', 'ceramic', 'porcelain']
#
#
# ['stretch', 'tie', 'wrap', 'wrapped', 'blanket', 'towel', 'scoop', 'foil']
#
#
# ['grass', 'lawn', 'artificial', 'synthetic', 'greens', 'turf']
#
#
# ['instruments', 'instrument']
#
#
# ['.1', '.5', '.0', '.2', '.3', 'iso', '.4', '.8', '.6', '.7']
#
#
# ['ratio', 'estimate', 'measurement', 'linear', 'density', 'measurements', 'calculator', 'calculated', 'calculate', 'algorithm', 'equation', 'probability', 'prediction', 'differential', 'calculation']
#
#
# ['virus', 'infected', 'viral', 'viruses', 'spyware']
#
#
# ['trained', 'educated', 'knowledgeable', 'technicians']
#
#
# ['seed', 'seeds']
#
#
# ['gender']
#
#
# ['ski', 'climbing', 'surfing', 'skiing', 'skating']
#
#
# ['finger', 'fingers', 'thumb', 'wrist']
#
#
# ['t1', 'broadband', 'bandwidth', 'voip', 'dsl']
#
#
# ['conservative', 'liberal', 'democrats', 'republicans', 'politicians', 'gop', 'conservatives', 'liberals']
#
#
# ['informed', 'consultation', 'inform', 'advise', 'notify', 'consult', 'advised', 'contacted', 'prospective', 'hesitate', 'contacting', 'kindly']
#
#
# ['booking', 'reservations', 'reservation']
#
#
# ['110', '102', '104', '106', '108', '112', '114']
#
#
# ['victims', 'victim', 'survived', 'survivors', 'survivor', 'surviving']
#
#
# ['directors', 'executives', 'shareholders']
#
#
# ['breath', 'breathing', 'oxygen', 'sweat', 'breathe']
#
#
# ['fiber', 'resistant', 'coating', 'coated', 'uv', 'resin', 'insulation', 'adhesive', 'polymer', 'drying']
#
#
# ['wildlife', 'conservation', 'habitat', 'forests', 'preservation']
#
#
# ['poetry', 'essay', 'essays', 'poem', 'verse', 'poems', 'poet', 'writings']
#
#
# ['nov.', 'jan.', 'feb.', 'oct.', 'dec.', 'sept.', 'aug.', 'dated', 'apr.', 'sept']
#
#
# ['chip', 'chips']
#
#
# ['sustainable', 'tourism', 'agriculture', 'agricultural', 'crop', 'farming', 'crops']
#
#
# ['bmw', 'audi', 'mercedes', 'rover']
#
#
# ['charity', 'donation', 'donations', 'donate', 'donated', 'fundraising', 'charitable', 'donor']
#
#
# ['icon', 'symbol', 'icons', 'symbols']
#
#
# ['anime', 'manga', 'hentai', 'naruto']
#
#
# ['ram', 'processor', 'cpu', 'ghz', 'processors']
#
#
# ['600', '800', '700', '900', '1200', '750', '650']
#
#
# ['sensor', 'sensors', 'detector']
#
#
# ['ms.', 'lisa', 'linda', 'karen', 'sue', 'marie', 'carol', 'lynn', 'sharon', 'betty', 'donna', 'jo', 'monica', 'eva', 'diana', 'sally', 'angela', 'diane', 'kathy', 'tracy', 'kay', 'jackie', 'sandra', 'judy', 'wendy', 'cindy', 'leslie', 'tina', 'paula']
#
#
# ['deposit', 'mineral', 'deposits']
#
#
# ['infection', 'hiv', 'immune', 'bacteria', 'infections', 'yeast', 'respiratory', 'tract']
#
#
# ['oven', 'grill', 'fireplace', 'heater', 'stove', 'burner']
#
#
# ['reflect', 'radiation', 'reflection', 'reflects', 'reflected', 'projected', 'sunlight', 'reflections']
#
#
# ['delete', 'disabled', 'deleted', 'reset', 'manually', 'configure', 'duplicate', 'disable']
#
#
# ['pen', 'pencil', 'marker', 'markers']
#
#
# ['metro', 'milwaukee', 'metropolitan', 'minneapolis', 'rapids', 'rochester', 'midwest']
#
#
# ['contractors', 'builder', 'builders', 'architects']
#
#
# ['lamp', 'bulb', 'bulbs', 'watt']
#
#
# ['muslim', 'jews', 'islam', 'arab', 'islamic', 'muslims']
#
#
# ['morgan']
#
#
# ['mg', 'pills', 'penis', 'tablets', 'pill', 'phentermine']
#
#
# ['consumption', 'calories', 'consuming', 'consume', 'consumed']
#
#
# ['mixture', 'mixing', 'mixer']
#
#
# ['intel', 'amd', 'nvidia']
#
#
# ['sponsored', 'sponsor', 'sponsors', 'vip', 'affiliated', 'affiliates']
#
#
# ['singapore', 'kong', 'hong', 'thailand', 'philippines', 'dubai', 'malaysia', 'bangkok']
#
#
# ['specifications', 'specs', 'specification', 'spec']
#
#
# ['sentence', 'sentences']
#
#
# ['delay', 'delayed', 'delays']
#
#
# ['knife', 'blades', 'knives']
#
#
# ['vitamin', 'supplement', 'supplements', 'vitamins', 'minerals', 'dietary', 'nutrients']
#
#
# ['relax', 'relaxing', 'meditation', 'relaxation']
#
#
# ['egypt', 'saudi', 'lebanon', 'nigeria', 'abu', 'arabia']
#
#
# ['susan', 'barbara', 'nancy', 'helen', 'ellen', 'ruth', 'joan', 'janet', 'patricia', 'louise']
#
#
# ['eligible', 'admission', 'qualify', 'applicants', 'applicant', 'enrollment', 'eligibility', 'admissions']
#
#
# ['export', 'import', 'imported', 'exports']
#
#
# ['pad', 'pads', 'mat', 'mats']
#
#
# ['engaged', 'engage', 'engaging', 'actively']
#
#
# ['wallpaper', 'wallpapers']
#
#
# ['bears', 'eagles', 'lions', 'jets', 'cowboys', 'patriots', 'bulls', 'lakers', 'ducks', 'chiefs', 'devils']
#
#
# ['liability', 'damages', 'liable']
#
#
# ['cure', 'remedy', 'remedies']
#
#
# ['seal', 'sealed', 'seals']
#
#
# ['eagle', 'cabin', 'scout', 'ranger', 'lone', 'scouts']
#
#
# ['+1', '-1', '-5', '-2', '+2', '-3']
#
#
# ['fraud', 'theft', 'corruption', 'conspiracy', 'scam', 'corrupt']
#
#
# ['1,000', '10,000', '100,000', '5,000', '2,000', '50,000', '20,000', '3,000']
#
#
# ['vertical', 'horizontal', 'axis']
#
#
# ['knee', 'ankle', 'elbow']
#
#
# ['sql', 'oracle', 'mysql']
#
#
# ['receiver', 'amp', 'antenna', 'rf', 'amplifier']
#
#
# ['penalty', 'penalties']
#
#
# ['subscription', 'subscribers', 'subscribed', 'subscriber']
#
#
# ['alpha', 'delta', 'chi', 'omega']
#
#
# ['nail', 'nails']
#
#
# ['jean', 'ralph', 'beverly', 'hardy', 'norton', 'dana', 'wang', 'heath', 'klein', 'calvin']
#
#
# ['witness', 'counsel', 'testimony', 'defendant', 'witnesses', 'plaintiff']
#
#
# ['1986', '1980', '1984', '1985', '1983', '1970', '1982', '1979', '1981', '1978', '1976', '1977', '1975', '1969', '1972', '1973', '1974', '1968', '1971']
#
#
# ['nuts', 'nut']
#
#
# ['mining', 'coal', 'exploration', 'pipeline', 'petroleum', 'mines', 'fossil']
#
#
# ['silk', 'satin', 'linen', 'ivory', 'velvet', 'faux', 'leopard']
#
#
# ['visa', 'passport']
#
#
# ['cooling', 'cooler', 'warmer']
#
#
# ['garlic', 'onion', 'potatoes', 'tomato', 'tomatoes', 'chopped', 'onions', 'apples', 'peppers', 'mushrooms']
#
#
# ['beans', 'bean', 'jelly']
#
#
# ['decor', 'decorative', 'balloon', 'decorating', 'decorations', 'decoration']
#
#
# ['bomb', 'blast', 'rocket', 'explosion', 'atomic', 'bombs']
#
#
# ['floors', 'tile', 'flooring', 'tiles']
#
#
# ['foreclosure', 'foreclosures']
#
#
# ['puzzle', 'arcade', 'chess', 'cube', 'puzzles']
#
#
# ['specialty', 'specialized', 'specializes', 'specializing', 'specialize']
#
#
# ['gloves', 'helmet', 'glove']
#
#
# ['richmond', 'kent', 'hilton', 'hampton', 'newport', 'kingston', 'charleston', 'essex', 'plymouth', 'windsor', 'norfolk', 'durham', 'providence', 'lexington', 'devon']
#
#
# ['giants', 'sox', 'pirates', 'tigers', 'rangers', 'yankees', 'cardinals', 'cubs']
#
#
# ['chevrolet', 'chevy', 'mustang', 'gmc']
#
#
# ['0.00', 'bids', '.00', 'postage', '1.00', '9.99', '5.00', '10.00']
#
#
# ['cord', 'nerve', 'spine', 'spinal']
#
#
# ['350', '450']
#
#
# ['stamp', 'stamps']
#
#
# ['lg', 'verizon', 'sprint', 'comcast', 'motorola', 'at&t']
#
#
# ['avi', 'mp4', 'wmv', 'mpeg']
#
#
# ['steal', 'stolen', 'possession', 'allegedly', 'stealing', 'stole', 'accidentally']
#
#
# ['mesh', 'nylon', 'lining', 'polyester', 'woven']
#
#
# ['cooked', 'roasted', 'grilled', 'roast']
#
#
# ['unto', 'thou', 'ye', 'thy', 'thee']
#
#
# ['tokyo', 'beijing', 'shanghai']
#
#
# ['flu', 'fever', 'vaccine', 'allergy', 'cough']
#
#
# ['edges', 'corners', 'lightly', 'rounded']
#
#
# ['rev.', 'res', 'rev']
#
#
# ['physically', 'mentally', 'sexually', 'abusive', 'financially', 'emotionally']
#
#
# ['socks', 'wool', 'knit', 'sweater', 'fleece', 'scarf', 'vest']
#
#
# ['bluetooth', 'headphones', 'headset']
#
#
# [':1', ':0', ':3', ':\\']
#
#
# ['drill', 'drilling', 'offshore', 'rig']
#
#
# ['terror', 'terrorist', 'terrorism', 'torture', '9/11', 'terrorists', 'cia', 'laden']
#
#
# ['noble', 'berry', 'mc', 'pioneer', 'pictured', 'moss', 'shepherd', 'porter', 'frost', 'bud', 'mayo']
#
#
# ['ethnic', 'tribal']
#
#
# ['jacob', 'genesis', 'abraham', 'moses', 'isaac', 'noah']
#
#
# ['slave', 'prisoners', 'slaves', 'slavery']
#
#
# ['diving', 'dive', 'shark', 'aquarium', 'turtle', 'reef', 'underwater', 'whale']
#
#
# ['drums', 'vocals', 'melody']
#
#
# ['terrace', 'balcony', 'overlooking', 'waterfront', 'courtyard']
#
#
# ['basement', 'closet', 'wardrobe', 'locker']
#
#
# ['1-2', '2-3', 'yrs', '3-4']
#
#
# ['sheep', 'cow', 'pig', 'mice', 'cattle', 'breeding', 'goat', 'rats', 'pigs']
#
#
# ['bedding', 'pillow', 'towels', 'cushion', 'pillows']
#
#
# ['retailers', 'merchant', 'merchants', 'traders']
#
#
# ['node', 'nodes']
#
#
# ['marijuana', 'weed', 'pest']
#
#
# ['turbo', 'gt', '911', 'porsche', 'ferrari']
#
#
# ['router', 'proxy', 'antivirus', 'firewall', 'encryption']
#
#
# ['microwave', 'dryer', 'refrigerator', 'fridge', 'washer', 'freezer', 'dishwasher']
#
#
# ['penn', 'stanford', 'dame', 'usc', 'notre']
#
#
# ['violation', 'jurisdiction', 'violations', 'prohibited', 'pursuant', 'statute', 'breach']
#
#
# ['3g', '4g']
#
#
# ['candle', 'wax', 'candles']
#
#
# ['herbal', 'herbs', 'herb']
#
#
# ['sewing', 'yarn', 'needle', 'knitting', 'stitch', 'embroidery']
#
#
# ['barcelona', 'chelsea', 'madrid', 'fc', 'arsenal', 'milan']
#
#
# ['aa', 'aaa']
#
#
# ['rug', 'rugs']
#
#
# ['discrimination', 'racist', 'racial', 'blacks', 'racism', 'whites']
#
#
# ['240', '220', '210', '320', '201', '202', '205', '230', '225', '301', '256', '212', '204', '203', '206']
#
#
# ['silicon', 'semiconductor']
#
#
# ['bitter', 'dip', 'spicy', 'sour', 'topped', 'yogurt', 'salsa']
#
#
# ['1960', '1967', '1950', '1965', '1966', '1964', '1963', '1900', '1920', '1962', '1961', '1945', '1940', '1959', '1930']
#
#
# ['halo', 'gears', 'ops']
#
#
# ['activation', 'activated', 'activate']
#
#
# ['escort', 'escorts']
#
#
# ['mpg']
#
#
# ['calcium', 'sodium']
#
#
# ['rpm', 'torque']
#
#
# ['3a', '2f']
#
#
# ['hughes', 'milton', 'hopkins']
#
#
# ['quarterback', 'qb']
#
#
# ['fragrance', 'perfume', 'scent']
#
#
# ['sap', 'analytics', 'bi', 'outsourcing', 'crm', 'erp']
#
#
# ['rays']
#
#
# ['britney', 'spears']
#
#
# ['arctic', 'polar']
#
#
# ['rendered', 'render', 'rendering']
#
#
# ['wagon', 'convertible', 'sedan', 'suv', 'coupe']
#
#
# ['insulin', 'hormone', 'glucose']
#
#
# ['agosorry']
#
#
# ['gaga', 'madonna']
#
#
# ['lookup']
