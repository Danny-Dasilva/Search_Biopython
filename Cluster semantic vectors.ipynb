# %%
from __future__ import division
from sklearn.cluster import KMeans
from numbers import Number
from pandas import DataFrame
import sys, codecs, numpy

# %%
class autovivify_list(dict):
  '''A pickleable version of collections.defaultdict'''
  def __missing__(self, key):
    '''Given a missing key, set initial value to an empty list'''
    value = self[key] = []
    return value

  def __add__(self, x):
    '''Override addition for numeric types when self is empty'''
    if not self and isinstance(x, Number):
      return x
    raise ValueError

  def __sub__(self, x):
    '''Also provide subtraction method'''
    if not self and isinstance(x, Number):
      return -1 * x
    raise ValueError

# %%
def build_word_vector_matrix(vector_file, n_words):
  '''Return the vectors and labels for the first n_words in vector file'''
  numpy_arrays = []
  labels_array = []
  with codecs.open(vector_file, 'r', 'utf-8') as f:
    for c, r in enumerate(f):
      sr = r.split()
      labels_array.append(sr[0])
      numpy_arrays.append( numpy.array([float(i) for i in sr[1:]]) )

      if c == n_words:
        return numpy.array( numpy_arrays ), labels_array

  return numpy.array( numpy_arrays ), labels_array

# %%
def find_word_clusters(labels_array, cluster_labels):
  '''Return the set of words in each cluster'''
  cluster_to_words = autovivify_list()
  for c, i in enumerate(cluster_labels):
    cluster_to_words[ i ].append( labels_array[c] )
  return cluster_to_words

# %%
if __name__ == "__main__":
  input_vector_file = "glove.42B.300d.txt" # Vector file input (e.g. glove.6B.300d.txt)
  n_words = 10000 # Number of words to analyze
  reduction_factor = .1 # Amount of dimension reduction {0,1}
  n_clusters = int( n_words * reduction_factor ) # Number of clusters to make
  df, labels_array = build_word_vector_matrix(input_vector_file, n_words)
  kmeans_model = KMeans(init='k-means++', n_clusters=n_clusters, n_init=10)
  kmeans_model.fit(df)

  cluster_labels  = kmeans_model.labels_
  cluster_inertia   = kmeans_model.inertia_
  cluster_to_words  = find_word_clusters(labels_array, cluster_labels)

  for c in cluster_to_words:
    print(cluster_to_words[c])
    print("\n")
# Out:
# [',', '.', 'and', '"', 'for', 'on', '-', 'with', 'by', 'at', '...', 'all', 'more', ';', "'", '&', 'home', 'work', '--', 'long', 'set', 'full', 'working', 'special', 'together', 'share', 'along', 'short', 'works', 'field', 'fine']
#
#
# ['the', 'of', 'a', 'in', 'is', "'s", 'this', 'from', 'an', 'my', 'one', 'new', 'his', 'their', 'our', 'first', 'into', 'its', 'best', 'world', 'part', 'each', 'same', 'own', 'every', 'top', 'another', 'place', 'between', 'point', 'whole', 'main', 'entire']
#
#
# ['to', 'up', 'out', 'me', 'get', 'them', 'us', 'then', 'back', 'go', 'him', 'right', 'take', 'off', 'down', 'come', 'again', 'give', 'let', 'put', 'away', 'left', 'save', 'stop', 'leave', 'turn', 'move', 'follow', 'bring', 'rest', 'break']
#
#
# [':', 'information', 'reviews', 'details', 'info', 'map', 'description', 'profile', 'id', 'zip', 'testimonials']
#
#
# ['i', '?', "n't", 'do', 'what', 'like', 'just', 'would', 'how', 'see', 'know', 'did', 'could', "'m", 'think', 'does', 'really', 'want', "'ve", 'why', "'ll", 'say', 'never', 'ca', 'might', 'ever', "'d", 'actually', 'probably', 'wanted', 'wo']
#
#
# [')', '(']
#
#
# ['that', 'it', 'are', 'as', 'have', 'was', 'we', 'but', 'they', 'he', 'has', 'so', 'about', 'there', 'when', 'which', 'who', 'some', 'also', 'had', 'been', 'were', 'people', 'she', 'now', 'only', 'than', 'most', 'said', 'well', 'because', 'even', 'much', 'where', 'made', 'those', 'being', 'while', 'still', 'both', 'few', 'found', 'however', 'having', 'though', 'once', 'yet', 'least', 'far', 'already', 'others', 'almost', 'although']
#
#
# ['you', 'be', 'or', 'your', 'not', 'will', 'can', 'if', 'no', 'any', 'should', 'without', 'must']
#
#
# ['!', '.....', 'reblogged', '....', '!!', '~', '!!!', '^', '!!!!', 'ha', 'omg', '!!!!!', 'yay', '!!!!!!', 'xx', 'lmao', 'sooo']
#
#
# ['|', '2012', '2011', '2010', '2009', '2008', '2013', '2007', '2014']
#
#
# ['$', '£', 'usd', 'us$', '0.00', 'bids', 'eur', '.00', 'postage', '1.00', '9.99', '5.00', '10.00']
#
#
# ['time', 'years', 'days', 'ago', 'months', 'weeks', 'duration']
#
#
# ['/', '1', '2', '3', '4', '5', '+', '6', '7', '0', '8', '9', '1-2', '2-3', '3-4']
#
#
# ['[', ']']
#
#
# ['other', 'these', 'many', 'such', 'different', 'including', 'local', 'include', 'several', 'among', 'various', 'common', 'specific', 'groups', 'activities', 'types', 'variety', 'multiple', 'forms', 'numerous', 'kinds', 'diverse', 'amongst', 'sorts', 'varied', 'varying']
#
#
# ['may', '#', 'views', '10', '12', '20', '15', '11', '30', '18', '14', '13', '16', '25', '24', '@', '17', '21', '19', '22', '23', '26', '28', '27', '29', '31']
#
#
# ['am', 'posted', 'post', 'comments', 'comment', 'reply', 'posts', 'permalink', 'anonymous', 'replies', 'trackback']
#
#
# ['her', 'friend', 'mother', 'wife', 'mom', 'daughter', 'husband', 'sister', 'queen', 'dad', 'princess', 'girlfriend', 'sisters', 'boyfriend', 'daddy', 'daughters', 'mama', 'cousin', 'mum', 'marry', 'mommy', 'grandmother', 'aunt', 'wives', 'grandma', 'youngest', 'maid']
#
#
# ['pm', '10:00', '9:00', '7:30', '11:00', '6:30', '10:30', '8:30', '9:30', '5:30', '11:30']
#
#
# ['good', 'here', 'make', 'great', 'way', "'re", 'too', 'going', 'little', 'look', 'got', 'things', 'better', 'always', 'looking', 'sure', 'keep', 'feel', 'making', 'getting', 'hard', 'try', 'done', 'enough', 'makes', 'doing', 'nice', 'bad', 'fun', 'pretty', 'everything', 'kind', 'trying', 'looks', 'simply', 'clear', 'couple', 'stuff', 'cool', 'ones', 'definitely', 'totally']
#
#
# ['>', 'related', 'tags', '>>', 'category', 'tagged', 'categories', 'topics', '›', 'keywords', 'miscellaneous']
#
#
# ['very', 'less', 'bit', 'become', 'quite', 'seems', 'rather', 'especially', 'sometimes', 'seem', 'perhaps', 'itself', 'completely', 'difficult', 'sort', 'particularly', 'complex', 'extremely', 'appear', 'appears', 'seemed', 'becomes', 'expensive', 'becoming', 'slightly', 'tough', 'usual', 'familiar', 'fairly', 'relatively', 'somewhat', 'rough', 'incredibly', 'increasingly', 'equally', 'complicated', 'surprisingly', 'seemingly', 'tricky']
#
#
# ['over', 'after', 'through', 'before', 'since', 'during', 'times', 'following', 'past', 'early', 'later', 'across', 'half', 'lost', 'recent', 'previous', 'late', 'period', 'middle', 'throughout', 'nearly', 'earlier', 'prior']
#
#
# ['use', 'used', 'using', 'power', 'uses', 'powered', 'usage', 'generator']
#
#
# ['two', 'three', 'four', 'five', 'six', 'ten', 'seven', 'eight', 'nine', 'seasons', 'twelve', 'consecutive', 'eleven']
#
#
# ['%', 'percent', 'cent', 'percentage']
#
#
# ['day', 'year', 'last', 'today', 'week', 'season', 'month', 'daily', 'weekend', 'yesterday']
#
#
# ['free', 'check', 'register', 'checking', 'checked', 'checks', 'scan', 'checkout']
#
#
# ['love', 'friends', 'loved', 'loving', 'lovers', 'friendship', 'lover', 'beloved', 'companion', 'loyal']
#
#
# ['need', 'change', 'able', 'important', 'needs', 'key', 'needed', 'step', 'ways', 'build', 'allow', 'necessary', 'effort', 'grow', 'steps', 'proper', 'raise', 'vital', 'crucial', 'needing']
#
#
# ['find', 'search', 'browse', 'searching', 'searches', 'browsing', 'locate', 'searched', 'finder']
#
#
# ['=', '<']
#
#
# ['business', 'company', 'companies', 'customers', 'clients', 'businesses', 'firm', 'partners', 'providers', 'firms', 'vendors', 'enterprises', 'outsourcing']
#
#
# ['life', 'mind', 'sense', 'nature', 'deep', 'beyond', 'self', 'dream', 'reality', 'thoughts', 'brain', 'vision', 'soul', 'experiences', 'desire', 'dreams', 'passion', 'memories', 'inner', 'universe', 'personality', 'minds', 'happiness', 'collective', 'genius', 'imagination', 'essence', 'motivation', 'consciousness', 'perception', 'conscious', 'desires', 'infinite', 'perfection', 'realm', 'senses', 'brains', 'ego', 'dreaming', 'curiosity', 'illusion', 'bliss']
#
#
# ['help', 'healthy', 'helps', 'helping', 'assist', 'healthier']
#
#
# ['video', 'clip', 'clips', 'thumb', 'reel']
#
#
# ['online', 'site', 'web', 'website', 'content', 'sites', 'pages', 'websites', 'hosting', 'affiliate', 'on-line', 'affiliates', 'e-commerce']
#
#
# ['high', 'level', 'low', 'higher', 'average', 'lower', 'levels', 'highest', 'grade', 'degrees', 'lowest', 'elevated']
#
#
# ['around', 'next', 'end', 'start', 'until', 'close', 'coming', 'soon', 'continue', 'return', 'ready', 'forward', 'track', 'starting', 'beginning', 'begin', 'reach', 'ahead', 'returns', 'ending', 'heading', 'thru', 'sometime', 'tuned']
#
#
# ['game', 'play', 'games', 'player', 'playing', 'players', 'played', 'plays']
#
#
# ['read', 'reading', 'writing', 'write', 'written', 'author', 'wrote', 'editor', 'writer', 'readers', 'reader', 'authors', 'writes', 'reads', 'reviewer']
#
#
# ['service', 'services', 'support', 'provide', 'offer', 'access', 'offers', 'provides', 'resources', 'effective', 'solutions', 'providing', 'offering', 'resource', 'dedicated', 'deliver', 'comprehensive', 'provider', 'affordable', 'reliable', 'extensive', 'delivering', 'offerings', 'high-quality', 'up-to-date', '24/7']
#
#
# ['school', 'students', 'student', 'schools', 'teachers', 'campus', 'elementary', 'grades', 'tuition']
#
#
# ['state', 'ohio', 'michigan', 'illinois', 'kansas', 'indiana', 'oregon', 'minnesota', 'iowa', 'oklahoma', 'wisconsin', 'dakota', 'montana', 'idaho', 'nebraska', 'wyoming']
#
#
# ['city', 'near', 'located', 'nearby', 'downtown', 'neighborhood', 'streets', 'metro', 'mall', 'nearest', 'plaza', 'metropolitan', 'subway', 'suburban']
#
#
# ['system', 'process', 'method', 'device', 'advanced', 'electronic', 'mode', 'processing', 'combination', 'motion', 'components', 'combined', 'integrated', 'efficient', 'component', 'dynamic', 'technique', 'capable', 'handling', 'flexible', 'optical', 'fiber', 'magnetic', 'conventional', 'mechanism', 'advantages', 'continuous', 'imaging', 'grid', 'matrix', 'precision', 'automated', 'plasma', 'precise', 'coupled', 'generating', 'compression', 'modes', 'mapping', 'silicon', 'simulation', 'composite', 'utilizing', 'integral', 'coding', 'structured', 'scanning', 'proprietary', 'passive', 'projection', 'positioning', 'ion', 'cad', 'modular', 'catalyst']
#
#
# ['news', 'blog', 'article', 'articles', 'feed', 'blogs', 'rss', 'blogging', 'blogger', 'podcast', 'feeds', 'headlines', 'bloggers', 'weblog', 'podcasts']
#
#
# ['under', 'number', 'name', 'case', 'within', 'based', 'type', 'form', 'current', 'above', 'either', 'given', 'example', 'action', 'via', 'private', 'note', 'standard', 'etc.', 'sign', 'limited', 'direct', 'cases', 'entry', 'regular', 'active', 'normal', 'directly', 'except', 'allowed', 'transfer', 'and/or', 'express', 'registered', 'fixed', 'separate', 'shared', 'etc', 'e.g.', 'i.e.', 'instance', 'preferred', 'reverse']
#
#
# ['available', 'added', 'source', 'section', 'provided', 'additional', 'included', 'addition', 'offered', 'sources', 'detailed', 'instructions', 'optional', 'documentation', 'supplied', 'arrangements', 'arrangement']
#
#
# ['show', 'live', 'series', 'shows', 'episode', 'shown', 'showing', 'showed', 'comedy', 'episodes']
#
#
# ['page', 'links', 'url', 'privacy', 'login', 'admin', 'navigation', 'wikipedia', 'bookmark', 'faq', 'portal', 'homepage', 'advertise', 'archived', 'wiki', 'prev', 'disclaimer', 'widget', 'embed', 'sitemap', 'dashboard']
#
#
# ['please', 'view', 'add', 'click', 'link', 'below', 'select', 'enter', 'menu', 'clicking', 'scroll', 'clicks', 'enlarge', 'thumbnail']
#
#
# ['big', 'large', 'huge', 'tiny', 'massive', 'giant', 'vast', 'enormous', 'mega']
#
#
# ['s', 'c', 'b', 'm', 't', 'd', 'r', 'l', 'f', 'g', 'h', 'p', 'j', 'k', 'q', 'z']
#
#
# ['family', 'children', 'kids', 'child', 'living', 'parents', 'families', 'parent', 'childhood', 'mothers', 'moms', 'spouse', 'parenting']
#
#
# ['music', 'song', 'lyrics', 'album', 'songs', 'tracks', 'albums', 'soundtrack', 'tunes', 'beatles', 'playlist', 'lyric', 'chords']
#
#
# ['something', 'thing', 'thought', 'someone', 'anything', 'tell', 'yes', 'everyone', 'anyone', 'nothing', 'maybe', 'idea', 'mean', 'remember', 'else', 'guys', 'wrong', 'myself', 'thinking', 'guess', 'exactly', 'happen', 'happened', 'anyway', 'wonder', 'hell', 'happens', 'imagine', 'seriously', 'meant', 'realize', 'folks', 'supposed', 'bet', 'everybody', 'anymore', 'nobody', 'happening', 'wondering', 'somebody', 'anybody', 'suppose', 'honestly', 'heck', 'clue', 'guessing']
#
#
# ['price', 'item', 'shipping', 'availability', 'quantity', 'sku', 'bulk', 'vat', 'quantities', 'qty']
#
#
# ['book', 'books', 'fiction', 'literature', 'classics', 'novels', 'textbooks']
#
#
# ['real', 'property', 'estate', 'homes', 'properties', 'mls', 'realty', 'estates', 'appraisal']
#
#
# ['old', 'young', 'age', 'older', 'younger', 'aged', 'aging', 'yrs', 'yr']
#
#
# ['black', 'white']
#
#
# ['house', 'party', 'called', 'taken', 'led', 'gave', 'brought', 'fair', 'whose', 'named', 'passed', 'followed', 'helped', 'raised', 'forced', 'victory', 'carried', 'roots', 'captured', 'accompanied']
#
#
# ['man', 'woman', 'lady', 'gentleman']
#
#
# ['lot', 'extra', 'lots', 'plenty', 'filled', 'bunch', 'decent', 'tons', 'packed', 'spare', 'loads', 'ton', 'endless', 'handful', 'extras', 'ample']
#
#
# ['health', 'care', 'medical', 'healthcare', 'medicare']
#
#
# ['group', 'national', 'society', 'association', 'organization', 'foundation', 'organizations', 'organized', 'alliance', 'organisation', 'coalition', 'civic', 'federation', 'associations', 'non-profit', 'organizing', 'nonprofit', 'cooperative', 'affiliated', 'organised']
#
#
# ['team', 'league', 'teams', 'coach', 'coaching', 'recruiting', 'coaches', 'squad', 'roster', 'recruit']
#
#
# ['car', 'parts', 'insurance', 'auto', 'vehicle', 'motor', 'automotive', 'automobile', 'motors']
#
#
# ['area', 'location', 'space', 'areas', 'places', 'region', 'zone', 'locations', 'urban', 'fields', 'surrounding', 'regions', 'spots', 'spaces', 'adjacent', 'zones', 'proximity']
#
#
# ['buy', 'sale', 'stock', 'purchase', 'sell', 'sold', 'bought', 'buying', 'selling', 'goods', 'purchased', 'ebay', 'auction', 'purchasing', 'merchandise', 'sells', 'purchases', 'swap', 'auctions', 'buys']
#
#
# ['money', 'pay', 'credit', 'account', 'cash', 'paid', 'payment', 'fee', 'paying', 'payments', 'deposit', 'transaction', 'settlement', 'pays', 'paypal', 'merchant', 'refund', 'receipt', 'billing', 'deposits', 'cancellation']
#
#
# ['water', 'dry', 'wet', 'dried', 'moisture', 'drying']
#
#
# ['data', 'database', 'query', 'registry', 'queries', 'databases', 'repository']
#
#
# ['small', 'size', 'larger', 'medium', 'smaller', 'bigger', 'sizes', 'sized', 'accommodate', 'smallest']
#
#
# ['x', 'km', 'mm', 'approximately', '1.5', '2.5', 'approx', '0.5', '0.1']
#
#
# ['list', 'listed', 'directory', 'listings', 'listing', 'lists', 'classified', 'classifieds', 'directories']
#
#
# ['design', 'custom', 'designs', 'designer', 'architecture', 'designers']
#
#
# ['women', 'men', 'ladies']
#
#
# ['public', 'district', 'council', 'committee', 'commission', 'mayor', 'elected', 'representatives', 'appointed', 'parliament', 'advisory', 'municipal']
#
#
# ['order', 'delivery', 'orders', 'delivered', 'ordered', 'shipped', 'ordering']
#
#
# ['call', 'calls', 'calling', 'telephone', 'tel', 'toll', '911']
#
#
# ['second', 'third', 'fourth', 'fifth', 'sixth', 'seventh', 'eighth', 'ninth']
#
#
# ['says', 'gets', 'guy', 'likes', 'wants', 'knows', 'loves', 'feels', 'tells', 'thinks', 'finds', 'puts', 'sees', 'asks', 'tries', 'cares', 'owns', 'whoever', 'loses', 'decides', 'understands']
#
#
# ['download', 'software', 'downloads', 'utilities', 'freeware', 'screenshot', 'shareware']
#
#
# ['program', 'centre', 'programme', 'bbc', 'programmes']
#
#
# ['night', 'morning', 'evening', 'tonight', 'tomorrow', 'afternoon', 'nights', 'eve', 'midnight', 'weekends']
#
#
# ['products', 'product', 'brand', 'manufacturer', 'manufacturers', 'brands', 'maker', 'manufactured', 'makers']
#
#
# ['review', 'recommend', 'recommended', 'directions', 'suggested', 'suggestions', 'recommendations', 'reviewed', 'guidance', 'appointment', 'consultation', 'suggestion', 'recommendation', 'advise', 'consult', 'advised', 'reviewing', 'follow-up', 'readings', 'recommends']
#
#
# ['against', 'attack', 'attacks', 'enemy', 'destroy', 'defend', 'enemies', 'defeat', 'opponent', 'tactics', 'attacked', 'opponents', 'defending', 'attacking', 'allies', 'opposing']
#
#
# ['center', 'hospital', 'clinic', 'wellness', 'rehabilitation', 'vet', 'rehab', 'veterinary', 'clinics']
#
#
# ['line', 'lines']
#
#
# ['thanks', 'oh', 'sorry', 'hi', 'hey', 'wow', 'hello', 'mate', 'pmi', 'cheers', 'congrats', 'ami', 'bye', 'moderator', 'p.s.']
#
#
# ['food', 'eat', 'eating', 'foods', 'meals', 'ate', 'snack', 'eaten', 'snacks', 'eats']
#
#
# ['open', 'opening', 'closed', 'opened', 'doors', 'shut', 'closing', 'opens', 'sealed', 'closure', 'closes']
#
#
# ['university', 'college', 'degree', 'graduate', 'faculty', 'scholarship', 'bachelor', 'alumni', 'graduation', 'harvard', 'graduated', 'phd', 'semester', 'ph.d.', 'undergraduate', 'stanford', 'graduates', 'mba', 'diploma', 'yale', 'enrolled', 'admissions']
#
#
# ['room', 'floor', 'rooms', 'dining', 'suite', 'desk', 'lobby', 'elevator', 'upstairs']
#
#
# ['god', 'jesus', 'christ', 'gospel']
#
#
# ['experience', 'quality', 'unique', 'excellent', 'outstanding', 'superior', 'reputation', 'authentic', 'finest', 'exceptional', 'extraordinary', 'hospitality', 'clarity', 'distinctive', 'culinary', 'simplicity', 'aesthetic']
#
#
# ['internet', 'network', 'communication', 'communications', 'networks', 'networking', 'telecommunications', 'lan']
#
#
# ['hotel', 'inn', 'suites', 'lodge', 'motel', 'marriott']
#
#
# ['job', 'jobs', 'salary', 'salaries', 'wage', 'wages', 'payroll']
#
#
# ['date', 'march', 'june', 'april', 'january', 'july', 'february', 'october', 'september', 'november', 'december', 'august']
#
#
# ['course', 'class', 'club', 'golf', 'master', 'classes', 'courses', 'masters']
#
#
# ['american', 'british', 'royal', 'canadian', 'australian', 'irish', 'britain']
#
#
# ['contact', 'email', 'name@domain.com', 'mail', 'e-mail', 'fax', 'contacts', 'spam', 'emails', 'mailing', 'sms']
#
#
# ['side', 'front', 'bottom', 'edge', 'flat', 'upper', 'sides', 'stretch', 'strip', 'outer', 'plates', 'pockets', 'edges', 'lined', 'corners', 'fold', 'lining', 'strips', 'lightly', 'rows', 'shallow', 'foil', 'rounded']
#
#
# ['county', 'carolina', 'georgia', 'alabama', 'tennessee', 'kentucky', 'missouri', 'louisiana', 'mississippi', 'arkansas']
#
#
# ['phone', 'mobile', 'cell', 'devices', 'phones', 'nokia', 'gps', 'cellular', 'sim']
#
#
# ['research', 'study', 'science', 'studies', 'institute', 'clinical', 'sciences', 'economics', 'biology', 'chemistry', 'biological', 'genetics', 'comparative']
#
#
# ['community', 'mission', 'youth', 'ministry', 'counseling', 'fellowship', 'missions', 'advocacy', 'outreach']
#
#
# ['art', 'arts', 'museum', 'artists', 'painting', 'contemporary', 'exhibition', 'exhibit', 'paintings', 'sculpture']
#
#
# ['body', 'hair', 'skin', 'beauty', 'makeup', 'facial', 'lip', 'cosmetics']
#
#
# ['easy', 'simple', 'quick', 'easier', 'instant', 'convenient', 'accessible', 'ease', 'convenience', 'handy', 'inexpensive', 'conveniently', 'straightforward', 'hassle']
#
#
# ['control', 'remote', 'controls', 'controlled', 'controller', 'controlling']
#
#
# ['story', 'stories', 'character', 'characters', 'adventure', 'novel', 'fantasy', 'drama', 'plot', 'mystery', 'romance', 'horror', 'adventures', 'tale', 'tales', 'fairy', 'narrative', 'detective', 'sequel', 'saga', 'chronicles', 'thriller']
#
#
# ['light', 'lights', 'lighting', 'lamp', 'lamps', 'bulb', 'bulbs', 'projector']
#
#
# ['de', 'en', 'y', 'el', 'se', 'con', 'que', 'es', 'lo', 'para', 'por', 'dos']
#
#
# ['country', 'government', 'states', 'united', 'u.s.', 'america', 'countries', 'union', 'nation', 'foreign', 'americans', 'officials', 'citizens', 'nations', 'authorities', 'citizen', 'governments', 'politicians', 'regime', 'unions', 'immigrants', 'corrupt', 'urged']
#
#
# ['market', 'industry', 'global', 'demand', 'consumer', 'markets', 'sector', 'trends', 'trend', 'marketplace', 'sectors']
#
#
# ['results', 'original', 'similar', 'terms', 'numbers', 'figure', 'match', 'names', 'actual', 'sets', 'detail', 'pattern', 'examples', 'maps', 'figures', 'patterns', 'exact', 'matches', 'matching', 'profiles', 'alternate', 'identical', 'variations', 'descriptions', 'combinations']
#
#
# ['person', 'personal', 'whether', 'matter', 'yourself', 'certain', 'individual', 'particular', 'themselves', 'whatever', 'unless', 'respect', 'knowing', 'ourselves', 'whenever', 'regardless', 'depends', 'ordinary', 'wherever', 'his/her']
#
#
# ['office', 'division', 'offices', 'branch', 'convention', 'affairs', 'chamber', 'commerce', 'berlin', 'bureau', 'd.c.', 'headquarters', 'capitol', 'embassy', 'homeland', 'vienna', 'geneva']
#
#
# ['international', 'agency', 'independent', 'established', 'authority', 'founded', 'establish', 'adopted', 'franchise', 'charter', 'establishment', 'establishing', 'commonwealth', 'colony', 'governing']
#
#
# ['report', 'according', 'reports', 'reported', 'mentioned', 'presented', 'described', 'stated', 'agreed', 'noted', 'issued', 'identified', 'explained', 'discussed', 'referred', 'confirmed', 'commented', 'expressed', 'pointed', 'referring', 'addressed', 'verified', 'responded', 'quoted', 'cited', 'publicly', 'remarks', 'concluded', 'compiled', 'examined', 'interviewed', 'highlighted', 'documented', 'acknowledged']
#
#
# ['per', 'million', 'billion', 'estimated', '1,000', '10,000', '100,000', '5,000', 'annually', '2,000', '50,000', '20,000', '3,000']
#
#
# ['air', 'flight', 'fly', 'flying', 'plane', 'aircraft', 'pilot', 'jet', 'aviation', 'helicopter', 'planes', 'airplane', 'pilots']
#
#
# ['hours', 'minutes', 'hour', 'seconds', 'minute', 'min', 'mile', 'mins', 'hrs']
#
#
# ['red', 'green', 'blue', 'pink', 'yellow', 'orange', 'golden', 'purple', 'colored', 'rainbow', 'neon']
#
#
# ['john', 'king', 'george', 'william', 'thomas', 'charles', 'henry', 'joseph', 'sir', 'prince', 'edward', 'duke', 'arthur', 'albert', 'francis', 'walter', 'philip', 'samuel', 'benjamin', 'earl', 'alfred', 'frederick']
#
#
# ['south', 'north', 'west', 'miles', 'east', 'central', 'western', 'southern', 'regional', 'northern', 'eastern', 'northwest', 'southwest', 'continental', 'southeast', 'northeast', 'nw', 'sw', 'prairie', 'plains', 'midwest', 'frontier']
#
#
# ['project', 'complete', 'final', 'completed', 'initial', 'completion', 'completing']
#
#
# ['management', 'client', 'manage', 'managed', 'managing', 'inventory', 'organize', 'manages', 'navigate']
#
#
# ['run', 'running', 'takes', 'goes', 'runs', 'starts', 'ends', 'turns', 'begins', 'breaks', 'passes', 'stops', 'drops', 'walks', 'reaches', 'enters', 'pulls']
#
#
# ['development', 'growing', 'creating', 'develop', 'developing', 'supporting', 'innovative', 'producing', 'emerging', 'designing', 'expanding', 'introducing', 'implementing', 'develops']
#
#
# ['100', '150', '120', '180', '130', '140', '160', '240', '128', '220', '170', '320', '135', '175', '230', '225']
#
#
# ['history', 'historical', 'cultural', 'historic', 'heritage', 'literary']
#
#
# ['general', 'notes', 'edition', 'reference', 'chapter', 'summary', 'manual', 'introduction', 'brief', 'overview', 'references', 'biography', 'revision', 'chapters', 'encyclopedia', 'citation', 'outline', 'timeline', 'handbook', 'atlas', 'ieee', 'geography', 'anatomy', 'in-depth']
#
#
# ['law', 'rights', 'legal', 'marriage', 'laws', 'immigration', 'divorce', 'adoption', 'citizenship']
#
#
# ['head', 'hand', 'position', 'held', 'hold', 'hands', 'stand', 'carry', 'arms', 'holding', 'draw', 'positions', 'heads', 'holds', 'carrying', 'holder', 'holders', 'stake', 'umbrella']
#
#
# ['problem', 're', 'question', 'questions', 'issue', 'subject', 'forum', 'answer', 'thread', 'topic', 'discussion', 'challenge', 'forums', 'answers', 'debate', 'threads', 'discussions', 'solved']
#
#
# ['york', 'ny', 'jersey', 'nj', 'nyc', 'brooklyn', 'manhattan', 'queens']
#
#
# ['hope', 'wish', 'wait', 'chance', 'fans', 'expect', 'waiting', 'luck', 'willing', 'lucky', 'hopefully', 'hoping', 'crowd', 'wanting', 'hopes', 'promised', 'expecting', 'settle', 'dig', 'sooner', 'hoped', 'eager', 'wishing', 'happily', 'meantime', 'cheer', 'someday', 'happier', 'retire']
#
#
# ['watch', 'watches', 'replica']
#
#
# ['hot', 'sexy', 'webcam', 'lingerie', 'bikini', 'bra', 'panties', 'stockings', 'petite']
#
#
# ['photo', 'photos', 'image', 'picture', 'images', 'photographs', 'photograph']
#
#
# ['movie', 'film', 'movies', 'films', 'documentary']
#
#
# ['media', 'writers', 'mainstream', 'editors', 'critics', 'journalism', 'journalists', 'reporters', 'scholars']
#
#
# ['members', 'participants', 'participate', 'subjects', 'participation', 'participating', 'attendance', 'participated', 'prospective', 'peers', 'participant', 'attendees']
#
#
# ['version', 'update', 'updated', 'updates', 'upgrade', 'versions', 'adobe', 'backup', 'oem', 'newer', 'updating', 'upgrades', 'upgraded', 'rom', 'firmware']
#
#
# ['started', 'went', 'came', 'took', 'finally', 'tried', 'worked', 'decided', 'himself', 'looked', 'turned', 'began', 'moved', 'kept', 'ended', 'eventually', 'ran', 'reached', 'stopped', 'fell', 'herself', 'pulled', 'walked', 'dropped', 'suddenly', 'headed', 'stood', 'pushed', 'drove', 'rolled', 'jumped', 'stepped', 'grabbed', 'quietly', 'approached', 'lifted', 'blew']
#
#
# ['file', 'files', 'folder', 'folders']
#
#
# ['road', 'rd', 'lane', 'highway', 'rd.']
#
#
# ['often', 'frequently', 'constantly', 'regularly', 'rarely', 'occasionally', 'frequent', 'consistently', 'repeated', 'occasional', 'repeatedly', 'continually', 'continuously']
#
#
# ['park', 'parks', 'gardens', 'wildlife', 'conservation', 'recreation', 'recreational', 'museums', 'playground']
#
#
# ['tv', 'channel', 'television', 'satellite', 'channels', 'hdtv']
#
#
# ['social', 'education', 'programs', 'educational', 'academic', 'literacy', 'educators']
#
#
# ['fact', 'believe', 'true', 'reason', 'cannot', 'agree', 'truth', 'trust', 'nor', 'accept', 'doubt', 'majority', 'aware', 'whom', 'personally', 'neither', 'committed', 'lie', 'assume', 'admit', 'believed', 'blame', 'argue', 'convinced', 'disagree', 'refuse', 'convince', 'acknowledge', 'believing', 'declare']
#
#
# ['visit', 'member', 'meet', 'join', 'welcome', 'met', 'host', 'guest', 'parties', 'joined', 'partner', 'guests', 'visiting', 'attend', 'fellow', 'visited', 'visits', 'invited', 'attended', 'resident', 'hosted', 'sponsored', 'joining', 'invite', 'attending', 'hosts', 'colleagues', 'sponsor', 'sponsors', 'vip', 'ambassador', 'welcomed', 'mentor', 'invites']
#
#
# ['single', 'plus', 'super', 'base', 'double', 'fan', 'pack', 'mini', 'max', 'premium', 'pocket', 'dual', 'twin', 'pen', 'hood', 'deluxe', 'triple', 'multi', 'combo', 'duo', 'dash', 'lite', 'dome', 'quad']
#
#
# ['points', 'goal', 'goals', 'yards', 'scored', 'offensive', 'offense', 'defensive', 'scoring', 'assists', 'streak', 'rushing', 'rebounds']
#
#
# ['plan', 'federal', 'plans', 'budget', 'administration', 'approved', 'proposed', 'draft', 'approval', 'bid', 'proposal', 'acquisition', 'revised', 'proposals', 'preliminary', 'epa', 'approve', 'interim']
#
#
# ['technology', 'systems', 'tech', 'technologies', 'innovation', 'technological', 'innovations']
#
#
# ['2006', '2005', '2004', '2003', '2000', '2002', '2001', '1999', '1998', '1997', '1996', '1995', '1994', 'pp.']
#
#
# ['possible', 'future', 'deal', 'lead', 'likely', 'risk', 'potential', 'serious', 'responsible', 'possibly', 'remains', 'leads', 'unknown', 'dangerous', 'permanent', 'immediate', 'possibility', 'ultimately', 'chances', 'temporary', 'danger', 'entering', 'harm', 'potentially', 'destruction', 'encounter', 'scenario', 'unlikely', 'prospect', 'pose', 'safer', 'compromise', 'leak', 'viable', 'spill']
#
#
# ['street', 'st.', 'st', 'avenue', 'ave', 'ave.']
#
#
# ['features', 'comes', 'gives', 'feature', 'touch', 'entertainment', 'featuring', 'brings', 'exclusive', 'appearance', 'presents', 'adds', 'meets', 'creates', 'delivers', 'produces', 'carries', 'showcase', 'combines', 'draws', 'builds', 'introduces', 'sensation', 'touches', 'boasts']
#
#
# ['means', 'further', 'upon', 'present', 'shall', 'thus', 'therefore', 'purpose', 'otherwise', 'basis', 'manner', 'reasonable', 'acts', 'forth', 'circumstances', 'extent', 'regard', 'consideration', 'hence', 'latter', 'additionally', 'acceptable', 'moreover', 'furthermore', 'nevertheless', 'ought', 'thereby', 'burden', 'accordingly', 'reasonably', 'likewise', 'necessity', 'consequently', 'whatsoever', 'consequence', 'render']
#
#
# ['windows', 'window', 'microsoft', 'vista', 'xp']
#
#
# ['code', 'rules', 'apply', 'applied', 'procedure', 'valid', 'applying', 'applicable', 'applies', 'transfers', 'exceptions']
#
#
# ['sex', 'gay', 'teen', 'porn', 'teens', 'anal', 'hardcore', 'lesbian', 'xxx', 'fetish', 'kissing', 'erotic', 'bondage', 'bbw', 'bi', 'interracial', 'lesbians']
#
#
# ['event', 'events', 'tour', 'tickets', 'ticket', 'dates', 'concert', 'stadium', 'venue', 'arena', 'venues', 'concerts', 'gig', 'reunion']
#
#
# ['card', 'cards']
#
#
# ['seen', 'saw', 'watching', 'seeing', 'caught', 'catch', 'watched', 'viewing', 'sight', 'catching', 'sights', 'glimpse', 'chasing']
#
#
# ['value', 'total', 'amount', 'difference', 'greater', 'values', 'compared', 'maximum', 'equal', 'zero', 'relative', 'ratio', 'absolute', 'gap', 'equivalent', 'achieved', 'sum', 'yield', 'counts', 'margin', 'offset', 'exceed', 'median', 'threshold', 'comparable', 'proportion', 'tolerance', 'fraction', 'minus']
#
#
# ['training', 'trained', 'trainer', 'instructor', 'trainers', 'instructors']
#
#
# ['beautiful', 'amazing', 'wonderful', 'awesome', 'lovely', 'fantastic', 'gorgeous', 'incredible', 'brilliant', 'impressive', 'stunning', 'fabulous', 'superb', 'spectacular', 'magnificent', 'terrific', 'glorious', 'exquisite']
#
#
# ['security', 'safe', 'secure', 'secured', 'encryption']
#
#
# ['board', 'panel', 'boards', 'directors']
#
#
# ['learn', 'learned', 'lessons', 'taught', 'lesson', 'studying', 'studied', 'practicing']
#
#
# ['happy', 'thank', 'dear', 'wishes', 'congratulations', 'grateful', 'bless', 'brave', 'goodbye', 'merry', 'thankful', 'darling', 'greetings']
#
#
# ['create', 'existing', 'generate', 'combine', 'implement', 'introduce', 'customized', 'transform', 'utilize', 'alter', 'incorporate', 'combining', 'customize', 'employ', 'integrate', 'construct', 'adapt', 'complement', 'coordinate', 'merge', 'elaborate']
#
#
# ['computer', 'pc', 'hardware', 'computers', 'desktop', 'gaming', 'electronics', 'keyboard', 'computing', 'pcs']
#
#
# ['heart', 'hearts', 'souls']
#
#
# ['building', 'houses', 'buildings', 'residential', 'structures', 'architectural', 'towers']
#
#
# ['girl', 'girls', 'boy', 'boys', 'kid', 'teenage', 'teenager']
#
#
# ['energy', 'solar', 'sustainable', 'electricity', 'renewable']
#
#
# ['face', 'faces', 'facing', 'faced']
#
#
# ['war', 'force', 'military', 'army', 'civil', 'forces', 'navy', 'combat', 'naval', 'tactical', 'civilian', 'deployed']
#
#
# ['user', 'application', 'users', 'tools', 'environment', 'applications', 'solution', 'tool', 'allows', 'platform', 'virtual', 'enterprise', 'allowing', 'supports', 'enable', 'capture', 'capabilities', 'real-time', 'enables', 'enabled', 'environments', 'capability', 'platforms', 'embedded', 'viewer', 'mobility', 'enabling', 'automation', 'unified', 'leverage']
#
#
# ['president', 'obama', 'bush', 'clinton', 'presidential', 'romney', 'barack', 'mccain', 'palin', 'kerry', 'hillary', 'gore', 'reagan', 'mitt', 'presidents']
#
#
# ['human', 'humans', 'humanity', 'beings', 'mankind']
#
#
# ['words', 'word', 'term', 'meaning', 'dictionary', 'keyword', 'phrase', 'phrases', 'expressions']
#
#
# ['travel', 'trip', 'journey', 'trips', 'traveling', 'abroad', 'overseas', 'travelers', 'travels', 'travelling', 'touring', 'traveled', 'traveler', 'expedition']
#
#
# ['perfect', 'setting', 'ideal', 'suitable', 'portable', 'compact', 'versatile', 'suited', 'desirable', 'ideally']
#
#
# ['cost', 'costs', 'fees', 'pricing', 'expenses', 'expense', 'overhead']
#
#
# ['store', 'shop', 'shopping', 'stores', 'cart', 'outlet', 'grocery', 'warehouse', 'depot', 'walmart']
#
#
# ['model', 'models', 'modeling']
#
#
# ['style', 'modern', 'fashion', 'comfortable', 'luxury', 'inspired', 'styles', 'elegant', 'casual', 'fancy', 'stylish', 'sophisticated', 'boutique', 'luxurious', 'chic', 'styling', 'wardrobe', 'refined', 'elegance', 'fashionable', 'sleek']
#
#
# ['sales', 'tax', 'net', 'income', 'quarter', 'taxes', 'revenue', 'profit', 'earnings', 'profits', 'gross', 'gains', 'revenues', 'excluding', 'gdp']
#
#
# ['taking', 'instead', 'worth', 'giving', 'spend', 'spent', 'sharing', 'keeping', 'putting', 'leaving', 'adding', 'spending', 'trouble', 'cutting', 'keeps', 'bringing', 'losing', 'saved', 'saving', 'cuts', 'raising', 'whilst', 'counting', 'saves', 'replacing', 'laying', 'wasted', 'fixing', 'clearing', 'digging', 'wasting']
#
#
# ['50', '40', 'no.', '60', '35', '32', '45', '36', '33', '48', '34', '42', '38', '37', '44', '55', '39', '41', '43', '46', '52', '47', '49', '51', '54', '56', '53', '58', '57', '59', '62', '61', '63']
#
#
# ['known', 'popular', 'leading', 'famous', 'recognized', 'widely', 'trusted', 'prominent', 'regarded', 'respected', 'well-known', 'renowned', 'distinguished', 'notable', 'award-winning', 'internationally', 'prestigious', 'influential', 'landmark']
#
#
# ['\\', '_', '{', '}', 'int', '__', 'void', 'null', '<<', 'var']
#
#
# ['drive', 'traffic', 'driving', 'driver', 'drivers', 'drives', 'taxi']
#
#
# ['talk', 'told', 'ask', 'asked', 'saying', 'talking', 'asking', 'telling', 'conversation', 'spoke', 'answered', 'discussing', 'conversations', 'answering', 'complaining', 'quoting', 'commenting', 'kindly']
#
#
# ['box', 'items', 'boxes', 'labels', 'container', 'frames', 'packs', 'packing', 'tray', 'containers', 'baskets', 'storing', 'cans']
#
#
# ['color', 'colors', 'bright', 'colour', 'contrast', 'bold', 'colours', 'neutral', 'shade', 'shine', 'shades', 'colorful', 'vibrant', 'shiny', 'glow', 'crisp', 'vivid']
#
#
# ['baby', 'pregnancy', 'pregnant', 'babies', 'feeding', 'infant', 'twins', 'toddler', 'infants']
#
#
# ['church', 'christian', 'catholic', 'churches', 'bishop', 'parish', 'baptist', 'chapel', 'cathedral', 'orthodox']
#
#
# ['natural', 'commercial', 'traditional', 'rich', 'smart', 'generation', 'ultimate', 'rare', 'pure', 'extreme', 'typical', 'universal', 'non', 'formula', 'genuine', 'signature', 'elite', 'steam', 'ultra', 'virgin', 'hybrid', 'micro', 'pre', 'anti', 'fusion', 'lighter', 'tier', 'semi']
#
#
# ['test', 'testing', 'tests', 'inspection', 'screening', 'validation']
#
#
# ['major', 'largest', 'biggest', 'greatest', 'worst', 'worlds', 'oldest', 'fastest', 'hottest', 'closest', 'easiest', 'longest', 'hardest']
#
#
# ['performance', 'audience', 'musical', 'acting', 'performances', 'roles', 'actors', 'productions', 'producers', 'audiences', 'appearances', 'performers']
#
#
# ['uk', 'australia', 'zealand', 'nsw', 'nz']
#
#
# ['enjoy', 'enjoyed', 'pleasure', 'enjoying', 'enjoys', 'enjoyment']
#
#
# ['collection', 'library', 'archives', 'catalog', 'collections', 'libraries', 'catalogue']
#
#
# ['range', 'wide', 'ranging', 'ranges']
#
#
# ['rate', 'rates']
#
#
# ['marketing', 'campaign', 'ad', 'advertising', 'ads', 'logo', 'promotion', 'pr', 'promotional', 'banner', 'campaigns', 'advertisement', 'advertisements', 'branding', 'publicity', 'logos', 'commercials']
#
#
# ['digital', 'camera', 'cameras', 'canon', 'zoom', 'nikon']
#
#
# ['court', 'decision', 'rule', 'justice', 'appeal', 'supreme', 'courts', 'ruling', 'appeals', 'ruled', 'judicial']
#
#
# ['due', 'result', 'pressure', 'associated', 'significant', 'damage', 'exposure', 'resistance', 'resulting', 'rapid', 'losses', 'substantial', 'excess', 'subsequent', 'minimal', 'resulted', 'partial', 'damages', 'excessive', 'wound', 'strain', 'discharge', 'sustained', 'surge', 'defects']
#
#
# ['sound', 'record', 'records', 'audio', 'studio', 'recording', 'recorded', 'recordings', 'recorder', 'playback']
#
#
# ['send', 'message', 'sent', 'letter', 'signed', 'messages', 'letters', 'sending', 'sends', 'correspondence', 'incoming']
#
#
# ['professional', 'experienced', 'expert', 'professionals', 'experts', 'specialist', 'associates', 'specialty', 'consultants', 'skilled', 'specialists', 'specialized', 'architects', 'practitioners', 'specializes', 'referral', 'specializing', 'relocation', 'specialize', 'technicians']
#
#
# ['problems', 'issues', 'involved', 'situation', 'regarding', 'concerned', 'decisions', 'interests', 'challenges', 'matters', 'concerns', 'concern', 'dealing', 'conflict', 'situations', 'concerning', 'risks', 'involving', 'relating', 'consequences', 'demands', 'complaints', 'resolve', 'difficulties', 'ethical', 'resolved', 'addressing', 'dealt', 'controversy', 'arise', 'urgent', 'conflicts', 'considerations', 'dangers']
#
#
# ['includes', 'consists', 'composed', 'consisting', 'consist', 'comprised']
#
#
# ['english', 'language', 'speak', 'speaking', 'speech', 'languages', 'translation', 'speaks', 'spoken', 'translated', 'translate', 'arabic', 'hindi']
#
#
# ['cover', 'covered', 'coverage', 'covers', 'sections', 'covering', 'panels', 'barrier', 'openings']
#
#
# ['beach', 'sea', 'coast', 'marine', 'ocean', 'pacific', 'sand', 'atlantic', 'waters', 'shore', 'gulf', 'tropical', 'sandy', 'paradise', 'sunset', 'caribbean', 'surf', 'beaches', 'coastal', 'coral', 'tide', 'breeze', 'mediterranean', 'arctic', 'reef']
#
#
# ['stay', 'remain', 'quiet', 'stayed', 'staying', 'residence', 'overnight', 'stays']
#
#
# ['pictures', 'videos', 'gallery', 'pics', 'nude', 'naked', 'pic', 'galleries', 'cam', 'thumbs']
#
#
# ['address', 'domain', 'ip', 'addresses', 'protocol', 'postal', 'domains', 'protocols']
#
#
# ['financial', 'bank', 'finance', 'banks', 'accounts', 'accounting', 'banking', 'transactions', 'offshore', 'finances']
#
#
# ['guide', 'tips', 'advice', 'useful', 'helpful', 'tip', 'guides', 'tutorial', 'tricks', 'tutorials', 'hints']
#
#
# ['oil', 'oils']
#
#
# ['prices', 'cheap', 'deals', 'discount', 'cheaper', 'discounts', 'priced', 'cheapest', 'specials', 'bargain', 'discounted']
#
#
# ['star', 'stars', 'cast', 'actor', 'actress', 'starring', 'casting']
#
#
# ['press', 'published', 'magazine', 'journal', 'publication', 'publishing', 'publications', 'editorial', 'magazines', 'publishers', 'journals']
#
#
# ['policy', 'planning', 'projects', 'environmental', 'strategy', 'efforts', 'leadership', 'policies', 'relations', 'implementation', 'strategic', 'partnership', 'infrastructure', 'initiative', 'collaboration', 'cooperation', 'initiatives', 'sustainability', 'governance', 'collaborative', 'priorities', 'organizational', 'partnerships', 'coordination', 'budgets']
#
#
# ['latest', 'official', 'announced', 'launch', 'upcoming', 'planned', 'launched', 'announcement', 'announce', 'signing', 'announces', 'launches', 'announcements', 'rumors', 'anticipated', 'launching']
#
#
# ['la', 'le', 'un', 'du', 'pour', 'au', 'par', 'à', 'sur']
#
#
# ['department', 'director', 'manager', 'senior', 'executive', 'assistant', 'vice', 'representative', 'associate', 'principal', 'administrator', 'coordinator', 'supervisor', 'clerk', 'vp']
#
#
# ['title', 'label', 'titles', 'debut', 'entitled', 'ep', 'dated', 'lp', 'titled', 'compilation', 'excerpt']
#
#
# ['summer', 'fall', 'spring', 'winter', 'rise', 'falls', 'falling', 'rising', 'fallen', 'autumn', 'seasonal', 'rises']
#
#
# ['win', 'won', 'award', 'awards', 'winning', 'winner', 'contest', 'wins', 'prize', 'winners', 'oscar', 'prizes', 'trophy', 'lottery', 'nominated', 'contests', 'nomination', 'competitions']
#
#
# ['paper', 'print', 'sheet', 'papers', 'printed', 'sheets']
#
#
# ['town', 'village', 'cities', 'communities', 'rural', 'roads', 'province', 'towns', 'counties', 'districts', 'villages', 'neighborhoods']
#
#
# ['understand', 'explain', 'relevant', 'identify', 'describe', 'recognize', 'refer', 'solve', 'understood', 'communicate', 'demonstrate', 'evaluate', 'examine', 'inform', 'relate', 'precisely', 'assess', 'explaining', 'observe', 'analyze', 'describing', 'grasp']
#
#
# [':)', 'lol', ':d', 'haha', ';)', 'xd', ':p', ':-)', 'btw', '=)', 'anyways', 'hahaha', ';-)', 'hehe']
#
#
# ['friday', 'sunday', 'saturday', 'monday', 'thursday', 'tuesday', 'wednesday']
#
#
# ['weight', 'loss', 'fat', 'lose', 'diet', 'calories', 'lean', 'weigh', 'weights']
#
#
# ['staff', 'employees', 'workers', 'employment', 'labor', 'employee', 'managers', 'personnel', 'employer', 'worker', 'employers', 'hiring', 'workplace', 'executives', 'workforce', 'administrators']
#
#
# ['death', 'lives', 'dead', 'die', 'alive', 'victims', 'survive', 'dying', 'deaths', 'dies', 'fate', 'survived', 'tragedy', 'survivors', 'survivor', 'surviving']
#
#
# ['sports', 'sport', 'clubs', 'athletic', 'leisure', 'cricket', 'sporting', 'rugby']
#
#
# ['google', 'yahoo', 'myspace', 'messenger', 'gmail', 'msn', 'skype', 'aol']
#
#
# ['gold', 'silver', 'sterling', 'oval', 'plated', '14k']
#
#
# ['london', 'oxford', 'cambridge', 'kent', 'birmingham', 'bristol', 'derby', 'essex', 'plymouth', 'durham', 'brighton']
#
#
# ['act', 'accordance', 'provisions', 'provision', 'paragraph', 'clause', 'obligations', 'treaty', 'amended', 'pursuant', 'statute']
#
#
# ['wedding', 'dress', 'dresses', 'bride', 'skirt', 'bridal', 'prom', 'gown']
#
#
# ['usually', 'longer', 'generally', 'produce', 'depending', 'typically', 'normally', 'tend', 'grown', 'naturally', 'amounts', 'vary', 'commonly', 'fewer', 'periods', 'whereas', 'shorter', 'grows', 'tends', 'lesser', 'traditionally', 'varies', 'consuming', 'consume', 'consumed']
#
#
# ['san', 'francisco', 'seattle', 'diego', 'sf', 'berkeley']
#
#
# ['david', 'mr.', 'mark', 'james', 'paul', 'dr.', 'michael', 'robert', 'peter', 'richard', 'martin', 'mr', 'andrew', 'daniel', 'adam', 'captain', 'stephen', 'patrick', 'anthony', 'simon', 'matthew', 'alan', 'christopher', 'jonathan', 'steven', 'luke', 'roger', 'ian', 'marc', 'neil', 'vincent', 'nathan', 'colin', 'jeffrey', 'nicholas', 'timothy', 'adrian', 'julian']
#
#
# ['release', 'released', 'releases', 'releasing']
#
#
# ['currently', 'recently', 'became', 'changed', 'originally', 'immediately', 'returned', 'previously', 'accepted', 'appeared', 'entered', 'replaced', 'newly', 'officially', 'initially', 'remained', 'gained', 'acquired', 'shortly', 'declared', 'settled', 'formerly', 'begun', 'hired', 'transferred', 'blocked', 'banned', 'assumed', 'abandoned', 'appearing', 'briefly', 'occupied', 'subsequently', 'cleared', 'declined', 'promoted', 'reportedly', 'emerged', 'temporarily', 'acted', 'advertised']
#
#
# ['table', 'chair', 'tables', 'chairs']
#
#
# ['required', 'requirements', 'require', 'appropriate', 'requires', 'minimum', 'registration', 'criteria', 'requirement', 'admission', 'acceptance', 'requiring', 'strict', 'mandatory', 'applicant', 'qualifications', 'verification', 'enrollment']
#
#
# ['fire', 'burn', 'burning', 'burns', 'flame', 'burned', 'fires', 'flames', 'burner']
#
#
# ['inside', 'cut', 'piece', 'machine', 'ground', 'block', 'pieces', 'count', 'fill', 'load', 'replace', 'row', 'raw', 'remaining', 'split', 'plain', 'empty', 'counter', 'root', 'column', 'blocks', 'shell', 'loading', 'loaded', 'bits', 'insert', 'filling', 'blank', 'stack', 'rolls', 'scratch', 'sticks', 'substitute', 'freeze', 'sticky', 'dice', 'straw']
#
#
# ['sun', 'earth', 'moon', 'planet', 'mars', 'eclipse']
#
#
# ['favorite', 'classic', 'favourite', 'favorites', 'newest', 'fav']
#
#
# ['behind', 'outside', 'walk', 'walking', 'corner', 'sit', 'sitting', 'standing', 'stands', 'tall', 'lay', 'opposite', 'rocks', 'entrance', 'bench', 'lying', 'surrounded', 'pit', 'shed', 'sits', 'bare', 'beneath', 'lap', 'beside', 'fountain', 'stairs', 'lit', 'underneath', 'statue', 'pictured', 'proudly', 'staring']
#
#
# ['dog', 'rescue', 'puppy', 'breed', 'puppies', 'shepherd']
#
#
# ['u', 'im', 'dont', 'shit', 'thats', 'damn', 'cant', 'dude', 'ur', 'kinda', 'ill', 'alot', 'didnt', 'wont', 'whats', 'ive', 'doesnt', 'tho', 'cuz', 'bout', 'bro', 'hes', 'isnt', 'ppl', 'dat', 'theres', 'cos', 'wat', 'fuckin']
#
#
# ['california', 'los', 'angeles', 'sacramento', 'l.a.']
#
#
# ['interest', 'continued', 'progress', 'continues', 'commitment', 'long-term', 'continuing', 'expansion', 'ongoing', 'dialogue', 'involvement', 'developments', 'advances', 'negotiations', 'renewal', 'renewed', 'short-term']
#
#
# ['meeting', 'meetings', 'agenda', 'conferences', 'appointments', 'committees', 'informal']
#
#
# ['rock', 'pop', 'folk', 'indie']
#
#
# ['fast', 'speed', 'slow', 'faster', 'pace', 'mph', 'speeds', 'rpm', 'slower', 'quicker']
#
#
# ['choose', 'choice', 'options', 'option', 'selection', 'choices', 'choosing', 'selecting', 'preference', 'preferences', 'selections']
#
#
# ['hit', 'hits', 'strike', 'struck', 'hitting', 'strikes', 'striking']
#
#
# ['n', 'e', 'w', 'o', 'da', 'di']
#
#
# ['created', 'designed', 'built', 'developed', 'produced', 'specifically', 'introduced', 'tested', 'implemented', 'constructed', 'specially', 'evolved', 'invented', 'prototype']
#
#
# ['treatment', 'treat', 'treated', 'treatments', 'treating']
#
#
# ['bill', 'bills']
#
#
# ['land', 'territory', 'lands']
#
#
# ['cause', 'blood', 'caused', 'causes', 'causing', 'bleeding', 'complications']
#
#
# ['band', 'bands']
#
#
# ['text', 'pdf', 'html', 'php', 'javascript', 'excel', 'xml', 'css']
#
#
# ['customer', 'seller', 'buyers', 'buyer', 'sellers']
#
#
# ['police', 'chief', 'officer', 'officers', 'commissioner', 'deputy', 'commander', 'sheriff', 'spokesman']
#
#
# ['changes', 'role', 'activity', 'relationship', 'factors', 'factor', 'relationships', 'influence', 'importance', 'perspective', 'evolution', 'differences', 'explains', 'suggests', 'survival', 'observed', 'describes', 'diversity', 'stem', 'absence', 'demonstrated', 'transformation', 'dynamics', 'underlying', 'implications', 'variation', 'reflects', 'significance', 'influenced', 'migration', 'phenomenon', 'suggesting', 'complexity', 'bias', 'origins', 'influences', 'demonstrates', 'adaptation', 'mortality', 'relevance', 'progression', 'explores']
#
#
# ['equipment', 'supply', 'supplies', 'wholesale', 'dealer', 'suppliers', 'supplier', 'vendor', 'distributor']
#
#
# ['usa', 'portland', 'charlotte', 'columbus', 'nashville', 'minneapolis', 'springfield', 'albany', 'charleston', 'rapids', 'rochester', 'salem', 'hometown', 'providence', 'princeton', 'raleigh', 'lexington', 'hartford']
#
#
# ['hotels', 'accommodation', 'accommodations', 'lodging', 'b&b', 'tripadvisor', 'hostel']
#
#
# ['washington', 'virginia', 'massachusetts', 'maryland', 'connecticut', 'maine', 'hampshire', 'delaware', 'vermont', 'rhode']
#
#
# ['interesting', 'exciting', 'surprise', 'dramatic', 'entertaining', 'fascinating', 'remarkable', 'surprising', 'unexpected', 'memorable', 'inspiring', 'compelling', 'profound', 'shocking', 'tragic', 'disturbing', 'disappointing']
#
#
# ['strong', 'solid', 'powerful', 'strength', 'sharp', 'weak', 'stronger', 'robust', 'strongest']
#
#
# ['bar', 'lounge', 'cafe', 'grill', 'pub', 'salon', 'bakery']
#
#
# ['hear', 'heard', 'listen', 'hearing', 'listening', 'tune', 'listened']
#
#
# ['received', 'receive', 'receiving', 'receives', 'recipient', 'recipients']
#
#
# ['door', 'mirror', 'lock', 'keys', 'seal', 'locked', 'mirrors', 'locks', 'handles', 'trunk', 'lid', 'sliding', 'locking', 'opener', 'windshield', 'seals']
#
#
# ['jan', 'feb', 'mar', 'apr', 'dec', 'jun', 'oct', 'nov', 'aug', 'sep', 'jul']
#
#
# ['christmas', 'gift', 'birthday', 'gifts', 'basket', 'personalized', 'easter', 'valentine', 'thanksgiving', 'favors']
#
#
# ['safety', 'protection', 'protect', 'protected', 'shield', 'protective', 'uv', 'protects', 'protector']
#
#
# ['wall', 'hang', 'hanging', 'ceiling', 'floating', 'hung', 'curtain']
#
#
# ['bed', 'sleep', 'beds', 'sleeping', 'couch', 'sofa', 'mattress', 'sleeps']
#
#
# ['material', 'structure', 'characteristics', 'composition', 'density', 'derived', 'orientation', 'qualities', 'characteristic', 'characterized']
#
#
# ['practice', 'learning', 'teacher', 'teaching', 'teach', 'math', 'instruction', 'classroom', 'curriculum', 'mathematics', 'discipline', 'teaches', 'hands-on']
#
#
# ['conference', 'session', 'workshop', 'sessions', 'summit', 'workshops', 'lecture', 'seminar', 'seminars', 'symposium', 'lectures']
#
#
# ['inc.', 'co.', 'corporation', 'inc', 'ltd', 'llc', 'ltd.', 'incorporated', 'corp.', 'corp']
#
#
# ['quote', 'quotes']
#
#
# ['lake', 'valley', 'hill', 'mountain', 'mount', 'creek', 'hills', 'mountains', 'peak', 'desert', 'ridge', 'canyon', 'rocky', 'mt', 'wilderness', 'mt.', 'terrain']
#
#
# ['production', 'materials', 'industrial', 'manufacturing', 'factory', 'industries', 'packaging', 'machinery', 'pharmaceutical', 'manufacture', 'semiconductor']
#
#
# ['brown', 'dark', 'grey', 'gray', 'tan', 'metallic', 'pale']
#
#
# ['radio', 'broadcast', 'fm', 'broadcasting']
#
#
# ['china', 'japan', 'asia', 'korea', 'singapore', 'kong', 'hong', 'vietnam', 'thailand', 'philippines', 'tokyo', 'indonesia', 'beijing', 'malaysia', 'taiwan', 'shanghai', 'bali', 'bangkok']
#
#
# ['eyes', 'eye', 'nose', 'finger', 'fingers', 'ear', 'lips', 'ears', 'chin']
#
#
# ['son', 'father', 'brother', 'brothers', 'sons', 'uncle', 'fathers', 'elder', 'grandfather']
#
#
# ['screen', 'display', 'graphics', 'lcd', 'displayed', 'displays', 'displaying', 'screens']
#
#
# ['engine', 'engines', 'turbo']
#
#
# ['texas', 'colorado', 'arizona', 'utah', 'nevada']
#
#
# ['ideas', 'basic', 'core', 'essential', 'concept', 'practical', 'aspects', 'philosophy', 'principles', 'framework', 'concepts', 'principle', 'fundamental', 'basics', 'essentials', 'foundations']
#
#
# ['increase', 'growth', 'increased', 'increasing', 'reduced', 'reduction', 'increases', 'significantly', 'greatly', 'consumption', 'decline', 'concentration', 'decrease', 'reduces', 'dramatically', 'decreased', 'circulation', 'considerably', 'appetite']
#
#
# ['dvd', 'cd', 'blu-ray', 'dvds']
#
#
# ['server', 'settings', 'module', 'setup', 'configuration', 'servers', 'cache', 'cluster', 'raid', 'configured', 'startup', 'deployment', 'configure', 'queue', 'dialog', 'partition', 'apache', 'authentication']
#
#
# ['canada', 'columbia', 'ontario', 'bc', 'nova', 'alberta', 'provincial']
#
#
# ['shot', 'shooting', 'shoot', 'shots', 'fired', 'firing', 'shoots', 'shooter']
#
#
# ['round', 'pick', 'straight', 'spot', 'pair', 'twice', 'picked', 'tie', 'tied', 'picks', 'picking', 'steal', 'handed', 'rounds', 'knock', 'quarters', 'hooked', 'knocked', 'stole', 'locker', 'doubles', 'sweep', 'keeper']
#
#
# ['island', 'islands', 'cape', 'isle', 'peninsula']
#
#
# ['clean', 'wash', 'dust', 'spray', 'brush', 'soap', 'washing', 'washed', 'wipe', 'dye']
#
#
# ['voice', 'solo', 'voices', 'vocal', 'vocals', 'rhythm', 'harmony', 'instrumental', 'organ', 'melody']
#
#
# ['born', 'died', 'married', 'birth', 'lived']
#
#
# ['india', 'indian', 'delhi', 'mumbai']
#
#
# ['mp3', 'ringtone', 'ringtones', 'midi']
#
#
# ['political', 'peace', 'movement', 'freedom', 'politics', 'reform', 'revolution', 'liberty', 'democracy', 'independence', 'labour', 'progressive', 'movements', 'radical', 'unity', 'revolutionary', 'equality', 'socialist', 'capitalism']
#
#
# ...
#
#
# ['acid', 'acids', 'sodium', 'fatty']
#
#
# ['till', 'den', 'til']
#
#
# ['disc', 'disk', 'discs']
#
#
# ['guarantee', 'warranty', 'guaranteed', 'lifetime', 'satisfaction', 'assured', 'assurance', 'guarantees']
#
#
# ['chemical', 'substance', 'chemicals', 'compound', 'toxic', 'particles', 'harmful', 'compounds', 'substances', 'hazardous']
#
#
# ['jazz', 'piano', 'opera', 'classical', 'orchestra', 'trio', 'choir', 'symphony', 'ensemble', 'violin']
#
#
# ['honor', 'recognition', 'ceremony', 'achievement', 'excellence', 'medal', 'honored', 'honors', 'achievements', 'dedication', 'merit', 'honour']
#
#
# ['stream', 'streaming', 'streams', 'flows', 'flowing']
#
#
# ['storm', 'disaster', 'flood', 'hurricane', 'lightning', 'earthquake', 'tornado', 'storms']
#
#
# ['memorial', 'funeral', 'buried', 'cemetery', 'grave', 'monument', 'burial']
#
#
# ['attached', 'attachment', 'attach']
#
#
# ['newspaper', 'newspapers']
#
#
# ['republican', 'candidate', 'candidates', 'democratic', 'conservative', 'liberal', 'democrats', 'republicans', 'gop', 'democrat', 'conservatives', 'liberals']
#
#
# ['mouse', 'rat', 'mice', 'rats']
#
#
# ['noise', 'laser', 'wave', 'frequency', 'waves', 'spectrum', 'radiation', 'beam', 'intensity', 'pulse', 'sensitivity', 'rf', 'interference']
#
#
# ['publisher', 'isbn', 'paperback', 'hardcover', 'isbn-13']
#
#
# ['serial', 'crack', 'torrent', 'keygen', 'hack', 'rapidshare', 'cracks']
#
#
# ['spain', 'barcelona', 'madrid', 'milan']
#
#
# ['del', 'costa', 'cruz', 'lopez', 'maya', 'marco', 'garcia']
#
#
# ['nfl', 'bears', 'giants', 'saints', 'eagles', 'jets', 'cowboys', 'patriots', 'chiefs']
#
#
# ['smoking', 'smoke', 'tobacco', 'cigarette', 'cigarettes']
#
#
# ['lens', 'sunglasses', 'lenses']
#
#
# ['era', 'decades', 'decade', 'mid', 'cult', '1980s', '1970s', '1960s', '80s', '1990s']
#
#
# ['spiritual', 'healing', 'meditation']
#
#
# ['anniversary', 'celebrate', 'celebration', 'celebrating', 'celebrated', 'celebrates', 'celebrations']
#
#
# ['rank', 'ranked', 'ranking', 'rankings', 'ranks', 'avg']
#
#
# ['20th', '19th', '21st', '18th', '15th', '17th', '16th', '13th', '14th', '25th', '30th', '24th', '28th', '22nd', '26th', '23rd', '27th', '29th', '31st']
#
#
# ['muscle', 'muscles']
#
#
# ['kick', 'jumping', 'kicked', 'kicks', 'spinning', 'kicking']
#
#
# ['bell', 'jr.', 'kennedy', 'wright', 'penn', 'jr', 'hughes', 'grounded', 'sr.', 'luther', 'cannon', 'hopkins']
#
#
# ['tower', 'castle', 'palace', 'mansion']
#
#
# ['illegal', 'arrested', 'suspect', 'guilty', 'victim', 'accused', 'theft', 'arrest', 'admitted', 'stolen', 'alleged', 'cops', 'scam', 'suspected', 'convicted', 'allegedly', 'cheating', 'stealing']
#
#
# ['seo', 'optimization', 'algorithm', 'analytics']
#
#
# ['ceo', 'chairman', 'founder', 'founding', 'entrepreneur']
#
#
# ['xbox', '360', 'wii', 'console', 'ps3', 'nintendo', 'playstation', 'ds', 'psp', 'cheat', 'cheats', 'ps2']
#
#
# ['roof', 'contractors', 'contractor', 'builders', 'insulation', 'roofing']
#
#
# ['hundred', 'thousand', 'twenty', 'dozen', 'roughly', 'bucks', 'thirty', 'fifty', 'fifteen', 'forty']
#
#
# ['kelly', 'terry', 'jamie', 'holly', 'blake', 'leo', 'tiffany', 'casey', 'hardy', 'tracy', 'dana', 'lindsay', 'riley', 'shannon', 'shane', 'joey', 'calvin']
#
#
# ['dental', 'teeth', 'tooth', 'dentist']
#
#
# ['earn', 'earned', 'credits', 'awarded', 'earning']
#
#
# ['singing', 'sing', 'chorus', 'sang', 'sings']
#
#
# ['hero', 'legend', 'epic', 'legacy', 'heroes', 'tribute', 'legendary', 'legends', 'iconic']
#
#
# ['certificate', 'certificates']
#
#
# ['ct', 'richmond', 'haven', 'hilton', 'nh', 'hampton', 'newport', 'kingston', 'manor', 'windsor', 'norfolk', 'chester']
#
#
# ['jacket', 'coat', 'sleeve', 'gloves', 'jackets', 'sleeves', 'glove', 'coats', 'fleece']
#
#
# ['pounds', 'lbs', 'lb', 'pound', 'kg', 'grams']
#
#
# ['lift', 'lifting', 'wheelchair', 'lifts']
#
#
# ['scheduled', 'delay', 'delayed', 'cancelled', 'delays']
#
#
# ['removal', 'restoration', 'restored', 'preservation']
#
#
# ['republic', 'polish', 'czech']
#
#
# ['java', 'python', 'c++']
#
#
# ['developer', 'consulting', 'consultant', 'hr', 'analyst', 'recruitment', 'advisor', 'architect', 'planner', 'freelance']
#
#
# ['threat', 'threats', 'threatened', 'threatening']
#
#
# ['mrs.', 'ann', 'jennifer', 'ms.', 'lisa', 'susan', 'amy', 'anne', 'laura', 'barbara', 'michelle', 'jean', 'nancy', 'linda', 'karen', 'robin', 'sue', 'marie', 'margaret', 'julie', 'heather', 'carol', 'lynn', 'helen', 'sharon', 'betty', 'melissa', 'mrs', 'donna', 'ellen', 'ruth', 'joan', 'jo', 'stephanie', 'janet', 'christine', 'andrea', 'jenny', 'christina', 'beth', 'diana', 'sally', 'angela', 'diane', 'kathy', 'kay', 'liz', 'jackie', 'sandra', 'judy', 'wendy', 'jill', 'cindy', 'leslie', 'patricia', 'louise', 'tina', 'paula']
#
#
# ['dish', 'salad', 'frozen', 'homemade', 'cooked', 'dressing', 'fried', 'baked', 'stuffed', 'dip', 'roasted', 'toast', 'grilled', 'topped', 'smoked']
#
#
# ['comic', 'animation', 'comics', 'cartoon', 'animated', 'coloring', 'cartoons']
#
#
# ['landscape', 'scenic', 'scenery', 'surroundings', 'countryside']
#
#
# ['tone', 'tones']
#
#
# ['1993', 'mercury', '1990', '1992', '1991', '1989', '1988', '1987', '1986', '1980', '1984', '1985', '1983', '1982', '1979', '1981', '1978', '1976', '1977', '1975', '1973', '1974']
#
#
# ['pants', 'jeans', 'swim', 'tops', 'shorts', 'socks', 'skinny', 'denim', 'underwear']
#
#
# ['occur', 'occurred', 'occurs', 'occurring']
#
#
# ['iran', 'turkish', 'egyptian', 'iranian', 'afghan']
#
#
# ['jpg', 'gif', 'png']
#
#
# ['monster', 'alien', 'robot', 'creatures', 'pokemon', 'monsters', 'creature', 'aliens', 'robots', 'dragons', 'zombies']
#
#
# ['lab', 'laboratory', 'labs', 'laboratories']
#
#
# ['laugh', 'replied', 'laughed', 'cried', 'smiled', 'laughs']
#
#
# ['legislation', 'constitution', 'amendment', 'constitutional', 'amendments']
#
#
# ['revealed', 'exposed', 'secrets', 'reveal', 'reveals', 'insider', 'revealing', 'expose']
#
#
# ['conduct', 'conducted', 'proceedings', 'trials', 'intervention', 'assisted', 'peer', 'conducting', 'voluntary', 'administered', 'initiated', 'termination']
#
#
# ['prison', 'jail', 'custody', 'prisoners', 'bail', 'juvenile', 'criminals', 'sentenced']
#
#
# ['101', '110', '125', '102', '105', '104', '106', '115', '103', '108', '112', '111', '107', '123', '109', '114', '116', '121', '118', '113', '122', '119', '117', '124', '126', '127']
#
#
# ['scheme', 'schemes']
#
#
# ['halloween', 'costume', 'mask', 'costumes']
#
#
# ['bone', 'tissue', 'bones', 'spine', 'skull', 'joints']
#
#
# ['wordpress', 'template', 'layout', 'templates', 'plugin', 'builder', 'header', 'cms']
#
#
# ['celebrity', 'celebrities', 'gossip', 'britney', 'spears', 'gaga', 'madonna']
#
#
# ['hunting', 'hunter', 'hunt', 'deer', 'hunters']
#
#
# ['qualified', 'eligible', 'visa', 'qualify', 'applicants', 'qualifying', 'nationals', 'eligibility', 'insured']
#
#
# ['nutrition', 'vitamin', 'supplement', 'supplements', 'vitamins', 'calcium', 'nutritional', 'dietary', 'nutrients']
#
#
# ['egg', 'eggs']
#
#
# ['victoria', 'sydney', 'melbourne', 'brisbane', 'queensland', 'perth', 'vic']
#
#
# ['hip', 'hop', 'punk', 'rap', 'hip-hop']
#
#
# ['antique', 'pottery', 'antiques']
#
#
# ['broad', 'narrow', 'scope', 'deeper', 'wider', 'broader']
#
#
# ['grass', 'lawn', 'artificial', 'synthetic', 'turf']
#
#
# ['cry', 'loud', 'tears', 'laughing', 'crying', 'asleep', 'screaming', 'smiling', 'laughter', 'scream', 'shout', 'shaking']
#
#
# ['instruments', 'instrument', 'tuning']
#
#
# ['.1', '.5', '.0', '.2', '.3', '.4', '.8', '.6', '.7', 'focal']
#
#
# ['collect', 'collected', 'gathering', 'gather', 'gathered', 'collecting', 'harvest', 'scattered']
#
#
# ['volunteer', 'volunteers', 'corps']
#
#
# ['virus', 'bacteria', 'viruses', 'spyware']
#
#
# ['soldiers', 'troops', 'armed', 'veterans', 'soldier', 'wounded', 'allied', 'infantry']
#
#
# ['gender', 'discrimination', 'racial', 'blacks', 'racism', 'whites']
#
#
# ['ski', 'skiing', 'skating']
#
#
# ['soil', 'agriculture', 'agricultural', 'crop', 'crops', 'planted', 'planting']
#
#
# ['pakistan', 'ali', 'khan', 'nigeria']
#
#
# ['t1', 'broadband', 'ethernet', 'bandwidth', 'comcast', 'voip', 'high-speed', 'dsl', 'telecom']
#
#
# ['booking', 'reservations', 'reservation', 'booked']
#
#
# ['dot', 'ribbon', 'stripes', 'dots', 'stripe']
#
#
# ['beta', 'alpha', 'delta', 'chi', 'omega']
#
#
# ['breath', 'breathing', 'sweat', 'breathe', 'urine']
#
#
# ['poetry', 'poem', 'poems', 'poet', 'shakespeare', 'inspirational', 'writings']
#
#
# ['logic', 'logical', 'solving', 'rational', 'reasoning']
#
#
# ['nov.', 'jan.', 'feb.', 'oct.', 'dec.', 'sept.', 'aug.', 'apr.', 'sept']
#
#
# ['outlook', 'export', 'import', 'imported', 'exports']
#
#
# ['kings', 'pirates', 'lions', 'mighty', 'warriors', 'thunder', 'knights', 'bulls', 'devils']
#
#
# ['hawaii', 'alaska', 'rico', 'hawaiian']
#
#
# ['tits', 'boobs', 'breasts', 'tit', 'nipples', 'booty']
#
#
# ['situated', 'spacious', 'terrace', 'balcony', 'furnished', 'overlooking', 'courtyard']
#
#
# ['bmw', 'audi', 'mercedes', 'porsche', 'ferrari', 'volkswagen', 'coupe', 'rover']
#
#
# ['charity', 'donation', 'donations', 'donate', 'proceeds', 'donated', 'fundraising', 'charitable', 'donor']
#
#
# ['anime', 'manga', 'hentai', 'naruto']
#
#
# ['loop', 'loops']
#
#
# ['formal', 'invitation', 'greeting', 'invitations', 'envelope']
#
#
# ['sensor', 'meters', 'meter', 'gauge', 'sensors']
#
#
# ['struggle', 'struggling', 'overcome', 'cope', 'struggles', 'struggled', 'troubled', 'troubles']
#
#
# ['manchester', 'liverpool', 'chelsea', 'fc', 'arsenal', 'newcastle', 'celtic', 'leeds', 'fa']
#
#
# ['believes', 'strongly', 'ban', 'ethics', 'abortion', 'seeks', 'advocate', 'discusses', 'raises', 'controversial', 'agrees', 'accepts', 'considers', 'stance', 'openly']
#
#
# ['adjustable', 'strap', 'mesh', 'removable', 'straps', 'elastic']
#
#
# ['infection', 'aids', 'hiv', 'flu', 'infections', 'vaccine', 'infected', 'viral']
#
#
# ['nba', 'nhl', 'finals', 'playoffs', 'playoff', 'lakers']
#
#
# ['oven', 'refrigerator', 'fridge', 'freezer']
#
#
# ['3.5', '4.5', '5.5', '7.5', '6.5', '8.5', '5.1']
#
#
# ['muslim', 'jews', 'christians', 'islam', 'islamic', 'muslims', 'allah']
#
#
# ['variable', 'parameters', 'linear', 'variables', 'parameter']
#
#
# ['intel', 'amd', 'nvidia']
#
#
# ['pitch', 'starter', 'rotation', 'pitcher', 'pitching', 'batting']
#
#
# ['specifications', 'specs', 'specification', 'gt', 'spec']
#
#
# ['sentence', 'sentences']
#
#
# ['carrier', 'carriers']
#
#
# ['brazil', 'rio', 'brazilian', 'portugal', 'rica', 'fifa']
#
#
# ['knife', 'blade', 'sword', 'blades', 'knives']
#
#
# ['valve', 'valves']
#
#
# ['smell', 'fragrance', 'perfume', 'scent', 'aroma']
#
#
# ['acres', 'sqft', 'sq', 'sq.', 'acre']
#
#
# ['corn', 'beans', 'potatoes', 'potato', 'tomatoes', 'onions', 'apples', 'mushrooms']
#
#
# ['relax', 'calm', 'relaxing', 'peaceful', 'relaxed', 'relaxation']
#
#
# ['census', 'genealogy', 'surname']
#
#
# ['cherry', 'lemon', 'berry', 'banana', 'lime', 'strawberry', 'peel', 'peach', 'citrus']
#
#
# ['genre', 'genres']
#
#
# ['arrival', 'departure']
#
#
# ['tiger', 'lion', 'monkey', 'zoo', 'safari', 'jungle', 'elephant', 'bunny', 'frog', 'turtle', 'sanctuary', 'penguin', 'whale', 'leopard']
#
#
# ['pad', 'mat', 'rug', 'mats']
#
#
# ['slot', 'slots']
#
#
# ['mens', 'womens', 'adidas']
#
#
# ['necklace', 'earrings', 'beads', 'bracelet', 'pendant', 'bead', 'charms', 'bracelets', 'quartz']
#
#
# ['cure', 'acne', 'heal', 'remedy', 'remedies', 'arthritis']
#
#
# ['wrap', 'lace', 'knit', 'blanket', 'yarn', 'knitting', 'sweater', 'scarf']
#
#
# ['lease', 'leasing']
#
#
# ['+1', '-1', '-5', '-2', '+2', '-3']
#
#
# ['na', 'sa', 'po']
#
#
# ['essay', 'essays', 'thesis']
#
#
# ['improvements', 'modification', 'modifications', 'additions']
#
#
# ['assigned', 'assignment', 'homework', 'assignments']
#
#
# ['jose', 'antonio', 'juan', 'carlos', 'luis']
#
#
# ['sql', 'ibm', 'oracle', 'mysql', 'sap']
#
#
# ['penalty', 'penalties']
#
#
# ['permit', 'permits', 'drilling']
#
#
# ['nail', 'nails']
#
#
# ['interaction', 'interactions', 'interact']
#
#
# ['nuts', 'nut']
#
#
# ['cloth', 'towel', 'towels']
#
#
# ['bankruptcy', 'foreclosure', 'foreclosures']
#
#
# ['passenger', 'passengers', 'cargo']
#
#
# ['landing', 'landed', 'flew']
#
#
# ['decor', 'decorative', 'balloon', 'decorating', 'decorations', 'decoration']
#
#
# ['bomb', 'blast', 'rocket', 'explosion', 'atomic', 'bombs']
#
#
# ['foam', 'gel', 'pads', 'glue', 'liner', 'adhesive', 'cushion']
#
#
# ['floors', 'tile', 'ceramic', 'flooring', 'marble', 'granite', 'tiles']
#
#
# ['tattoo', 'tribal', 'tattoos']
#
#
# ['puzzle', 'arcade', 'chess', 'cube', 'puzzles']
#
#
# ['toilet', 'sink', 'drain', 'basin', 'flush', 'vanity', 'mixer']
#
#
# ['doll', 'dolls', 'barbie']
#
#
# ['reporter', 'guardian', 'journalist', 'herald', 'tribune', 'chronicle', 'observer']
#
#
# ['stereo', 'headphones', 'headset']
#
#
# ['von', 'der', 'mit', 'und', 'das', 'ist']
#
#
# ['stroke', 'diagnosis', 'diagnosed', 'acute', 'diagnostic', 'tumor', 'cardiac']
#
#
# ['parade', 'carnival', 'circus', 'fireworks']
#
#
# ['grain', 'wheat']
#
#
# ['amp', 'watts', 'watt']
#
#
# ['5.0', '4.0', '0.0', '6.0']
#
#
# ['athletes', 'marathon', 'runner', 'athlete', 'runners']
#
#
# ['1970', '1969', '1972', '1968', '1960', '1971', '1967', '1950', '1965', '1966', '1964', '1963', '1900', '1920', '1962', '1961', '1945', '1940', '1959', '1930']
#
#
# ['stamp', 'stickers', 'stamps', 'sticker']
#
#
# ['avi', 'mp4', 'mpg', 'wmv', 'rar', 'rm', 'mpeg']
#
#
# ['indians', 'sox', 'tigers', 'rangers', 'mlb', 'yankees', 'rays', 'cardinals', 'cubs']
#
#
# ['execution', 'executed', 'execute']
#
#
# ['12:00', '8:00', '7:00', '6:00', '5:00', '1:00', '2:00', ':00', '4:00', '3:00']
#
#
# ['cartridge', 'toner', 'cartridges']
#
#
# ['unto', 'thou', 'thy', 'thee']
#
#
# ['pastor', 'rev.', 'rev']
#
#
# ['climbing', 'hiking', 'climb', 'ladder', 'steep']
#
#
# ['collar', 'vest']
#
#
# ['physically', 'mentally', 'sexually', 'politically', 'financially', 'emotionally']
#
#
# ['curve', 'equation', 'curves']
#
#
# ['oxygen', 'hydrogen']
#
#
# [':1', ':0', ':3', ':\\']
#
#
# ['si', 'ba', 'ce', 'mai', 'ta', 'ti', 'cu', 'pe']
#
#
# ['terror', 'terrorist', 'terrorism', 'torture', 'invasion', 'conspiracy', '9/11', 'terrorists', 'cia', 'laden']
#
#
# ['verizon', '3g', 'at&t', '4g']
#
#
# ['cooler']
#
#
# ['jacob', 'abraham', 'moses', 'joshua', 'isaac', 'noah']
#
#
# ['slave', 'slaves', 'slavery']
#
#
# ['diving', 'dive', 'surfing', 'underwater']
#
#
# ['ye']
#
#
# ['bedding', 'nursery']
#
#
# ['node', 'nodes']
#
#
# ['te', 'tu', 'su', 'je', 'ni']
#
#
# ['batman', 'marvel', 'superman']
#
#
# ['transparent', 'accountability', 'transparency']
#
#
# ['vid', 'vids']
#
#
# ['cosmetic']
#
#
# ['verse', 'prophet', 'genesis', 'revelation', 'romans']
#
#
# ['hudson']
#
#
# ['slideshow']
#
#
# ['pillow', 'rugs', 'pillows']
#
#
# ['bee', 'pest', 'bees']
#
#
# ['retro', 'disco', 'groove', 'funky', 'funk']
#
#
# ['router', 'proxy', 'ftp', 'antivirus', 'firewall']
#
#
# ['mc', 'ab', 'pioneer', 'frost', 'hay', 'cutter', 'mayo']
#
#
# ['microwave', 'dryer', 'stove', 'appliance', 'washer', 'dishwasher']
#
#
# ['violation', 'violations', 'breach']
#
#
# ['mineral', 'minerals']
#
#
# ['full-time', 'part-time']
#
#
# ['collector', 'collectors']
#
#
# ['candle', 'wax', 'candles']
#
#
# ['herbal', 'herbs', 'herb']
#
#
# ['sri', 'lanka']
#
#
# ['sewing', 'stitch', 'embroidery', 'embroidered']
#
#
# ['intermediate', 'beginner', 'beginners']
#
#
# ['bb', 'aa', 'aaa']
#
#
# ['punishment', 'harsh', 'wicked', 'brutal', 'abusive', 'cruel']
#
#
# ['src', 'img', 'hotel_review', 'href']
#
#
# ['v1', 'v2']
#
#
# ['soviet', 'communist', 'hitler', 'propaganda', 'nazi']
#
#
# ['cab', 'wagon', 'convertible', 'sedan', 'suv']
#
#
# ['puerto', 'cuba', 'haiti', 'panama', 'jamaica']
#
#
# ['guild', 'warcraft']
#
#
# ['antenna', 'microphone', 'mic', 'amplifier']
#
#
# ['blvd', 'hwy', 'ste', 'boulevard']
#
#
# ['acrylic', 'resin', 'polymer']
#
#
# ['doi', 'pubmed']
#
#
# ['activation', 'activated', 'activate']
#
#
# ['argentina', 'chile', 'peru']
#
#
# ['vegetarian', 'vegan']
#
#
# ['phentermine', 'tramadol']
#
#
# ['nerve', 'spinal']
#
#
# ['spelling', 'grammar', 'vocabulary']
#
#
# ['acer', 'toshiba', 'asus']
#
#
# ['handbags', 'vuitton', 'ugg', 'handbag']
#
#
# ['seafood', 'burger', 'sushi']
#
#
# ['3a', '2f']
#
#
# ['digg', 'technorati', 'bookmarks']
#
#
# ['singh']
#
#
# ['marker', 'markers']
#
#
# ['warfare', 'ops', 'battlefield']
#
#
# ['pipeline', 'crude', 'petroleum']
#
#
# ['innings', 'inning']
#
#
# ['asthma', 'allergy']
#
#
# ['dame', 'usc', 'notre']
#
#
# ['210', '201', '202', '205', '301', '256', '212', '204', '203', '206']
#
#
# ['holdings']
#
#
# ['+0000']
#
#
# ['smiles', 'hugs', 'hug']
#
#
# ['futures', 'commodity']
#
#
# ['insulin', 'hormone', 'metabolism', 'glucose']
#
#
# ['crm', 'erp']
#
#
# ['agosorry']
#
#
# ['hispanic', 'latino']
#
#
# ["'12", "'11"]
#
#
# ['shampoo', 'conditioner', 'lotion']
#
#
# ['cnet']
#
#
# ['nasdaq', 'nyse']
